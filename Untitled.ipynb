# %%
# %pip install nltk

import re
import sys

# File configuration
GROUP_NAME="Information_Retrieval_Group_Project"
INPUT_FILE="cran.all.1400"
OUTPUT_FILE=GROUP_NAME+"_processed.all"
STOPWORD_FILE="stopwords.txt"


# Splits text into word tokens
def tokenize(text):
    """Return alphabetic tokens from the given text."""

    tokens=re.findall(r"[A-Za-z]+",text)
    return tokens


# Applies Porter stemming
def stem(tokens,stemmer):
    """Stem every token."""

    stemmed_tokens=[]

    for token in tokens:
        stemmed_tokens.append(stemmer.stem(token))

    return stemmed_tokens


# Removes stop words
def remove_stopwords(tokens,stopwords):
    """Remove tokens present in the stop-word set."""

    result=[]

    for token in tokens:
        if token not in stopwords:
            result.append(token)

    return result


# Converts tokens to lowercase
def normalize(tokens):
    """Convert every token to lowercase."""

    return [token.lower() for token in tokens]


# Loads stop words from the file
def load_stopwords(filename):
    """Load one stop word from each line."""

    stopwords=set()

    try:
        with open(filename,"r",encoding="utf-8") as file:
            for line in file:
                word=line.strip().lower()

                if word:
                    stopwords.add(word)

    except FileNotFoundError:
        print("[ERROR] Stop-word file not found:",filename)
        sys.exit(1)

    print("[DEBUG] Loaded",len(stopwords),"stop words")

    return stopwords


# Processes one document
def process_document(text,stemmer,stopwords):
    """Tokenize,normalize,remove stop words and stem the text."""

    # Tokenization
    tokens=tokenize(text)
    print("[DEBUG] Tokens before processing:",len(tokens))

    # Normalization
    tokens=normalize(tokens)

    # Stop-word removal
    tokens=remove_stopwords(tokens,stopwords)
    print("[DEBUG] Tokens after stop-word removal:",len(tokens))

    # Stemming
    tokens=stem(tokens,stemmer)
    print("[DEBUG] Final tokens:",len(tokens))

    return tokens


# Processes the Cranfield collection
def preprocess_collection(input_file,output_file,stemmer,stopwords):
    """Process the title and abstract of every document."""

    current_doc_id=None
    current_section=None
    current_text=[]
    documents_processed=0

    try:
        input_fp=open(input_file,"r",encoding="utf-8")
    except FileNotFoundError:
        print("[ERROR] Input file not found:",input_file)
        sys.exit(1)

    output_fp=open(output_file,"w",encoding="utf-8")

    print("[DEBUG] Starting preprocessing:")
    print("[DEBUG] Input:",input_file)
    print("[DEBUG] Output:",output_file)

    # Writes the current document
    def process_current_document():
        nonlocal current_doc_id
        nonlocal current_text
        nonlocal documents_processed

        if current_doc_id is None:
            return

        # Combines the title and abstract
        text=" ".join(current_text)

        print("\n[DEBUG] Processing document:",current_doc_id)

        tokens=process_document(
            text,
            stemmer,
            stopwords
        )

        # Writes the document ID and tokens
        output_fp.write(".I "+current_doc_id+"\n")
        output_fp.write(".S\n")
        output_fp.write(" ".join(tokens)+"\n")

        documents_processed+=1
        current_text=[]

    # Reads the collection line by line
    for line in input_fp:
        line=line.rstrip("\n")

        # Starts a new document
        if line.startswith(".I"):
            process_current_document()

            parts=line.split()

            if len(parts)>=2:
                current_doc_id=parts[1]
            else:
                print("[WARNING] Invalid .I line:",line)
                current_doc_id=None

            current_section="I"

        # Starts the title
        elif line.startswith(".T"):
            current_section="T"

        # Starts the abstract
        elif line.startswith(".W"):
            current_section="W"

        # Ignores the author section
        elif line.startswith(".A"):
            current_section="A"

        else:
            # Stores only title and abstract text
            if current_section=="T" or current_section=="W":
                current_text.append(line)

    # Writes the last document
    process_current_document()

    input_fp.close()
    output_fp.close()

    print("[DEBUG] Preprocessing complete")
    print("[DEBUG] Documents processed:",documents_processed)
    print("[DEBUG] Output file:",output_file)


# Runs the preprocessing program
def main():
    print(" Cranfield Text Preprocessor")

    try:
        from nltk.stem import PorterStemmer
    except ImportError:
        print("[ERROR] NLTK is not installed.")
        print("Install using:")
        print("    pip install nltk")
        sys.exit(1)

    stemmer=PorterStemmer()
    stopwords=load_stopwords(STOPWORD_FILE)

    preprocess_collection(
        INPUT_FILE,
        OUTPUT_FILE,
        stemmer,
        stopwords
    )


if __name__=="__main__":
    main()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /Users/pranavi/Library/Python/3.9/lib/python/site-packages (3.9.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/pranavi/Library/Python/3.9/lib/python/site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: joblib in /Users/pranavi/Library/Python/3.9/lib/python/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: tqdm in /Users/pranavi/Library/Python/3.9/lib/python/site-packages (from nltk) (4.67.3)
# Requirement already satisfied: click in /Users/pranavi/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.8)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
#  Cranfield Text Preprocessor
# [DEBUG] Loaded 358 stop words
# [DEBUG] Starting preprocessing:
# [DEBUG] Input: cran.all.1400
# [DEBUG] Output: Information_Retrieval_Group_Project_processed.all
#
# [DEBUG] Processing document: 1
# [DEBUG] Tokens before processing: 150
# [DEBUG] Tokens after stop-word removal: 75
# [DEBUG] Final tokens: 75
#
# [DEBUG] Processing document: 2
# [DEBUG] Tokens before processing: 211
# [DEBUG] Tokens after stop-word removal: 122
# [DEBUG] Final tokens: 122
#
# [DEBUG] Processing document: 3
# [DEBUG] Tokens before processing: 36
# [DEBUG] Tokens after stop-word removal: 25
# [DEBUG] Final tokens: 25
#
# [DEBUG] Processing document: 4
# [DEBUG] Tokens before processing: 92
# [DEBUG] Tokens after stop-word removal: 53
# [DEBUG] Final tokens: 53
#
# [DEBUG] Processing document: 5
# [DEBUG] Tokens before processing: 75
# [DEBUG] Tokens after stop-word removal: 46
# [DEBUG] Final tokens: 46
#
# [DEBUG] Processing document: 6
# [DEBUG] Tokens before processing: 112
# [DEBUG] Tokens after stop-word removal: 56
# [DEBUG] Final tokens: 56
#
# [DEBUG] Processing document: 7
# [DEBUG] Tokens before processing: 229
# [DEBUG] Tokens after stop-word removal: 134
# [DEBUG] Final tokens: 134
#
# [DEBUG] Processing document: 8
# [DEBUG] Tokens before processing: 181
# [DEBUG] Tokens after stop-word removal: 85
# [DEBUG] Final tokens: 85
#
# [DEBUG] Processing document: 9
# [DEBUG] Tokens before processing: 324
# [DEBUG] Tokens after stop-word removal: 176
# [DEBUG] Final tokens: 176
#
# [DEBUG] Processing document: 10
# [DEBUG] Tokens before processing: 62
# [DEBUG] Tokens after stop-word removal: 34
# [DEBUG] Final tokens: 34
#
# [DEBUG] Processing document: 11
# [DEBUG] Tokens before processing: 112
# [DEBUG] Tokens after stop-word removal: 60
# [DEBUG] Final tokens: 60
#
# [DEBUG] Processing document: 12
# [DEBUG] Tokens before processing: 134
# [DEBUG] Tokens after stop-word removal: 75
# [DEBUG] Final tokens: 75
#
# [DEBUG] Processing document: 13
# [DEBUG] Tokens before processing: 145
# [DEBUG] Tokens after stop-word removal: 75
# [DEBUG] Final tokens: 75
#
# [DEBUG] Processing document: 14
# [DEBUG] Tokens before processing: 381
# [DEBUG] Tokens after stop-word removal: 220
# [DEBUG] Final tokens: 220
#
# [DEBUG] Processing document: 15
# [DEBUG] Tokens before processing: 143
# [DEBUG] Tokens after stop-word removal: 73
# [DEBUG] Final tokens: 73
#
# [DEBUG] Processing document: 16
# [DEBUG] Tokens before processing: 146
# [DEBUG] Tokens after stop-word removal: 79
# [DEBUG] Final tokens: 79
#
# [DEBUG] Processing document: 17
# [DEBUG] Tokens before processing: 149
# [DEBUG] Tokens after stop-word removal: 81
# [DEBUG] Final tokens: 81
#
# [DEBUG] Processing document: 18
# [DEBUG] Tokens before processing: 136
# [DEBUG] Tokens after stop-word removal: 65
# [DEBUG] Final tokens: 65
#
# [DEBUG] Processing document: 19
# [DEBUG] Tokens before processing: 74
# [DEBUG] Tokens after stop-word removal: 42
# [DEBUG] Final tokens: 42
#
# [DEBUG] Processing document: 20
# [DEBUG] Tokens before processing: 167
# [DEBUG] Tokens after stop-word removal: 100
# [DEBUG] Final tokens: 100
#
# [DEBUG] Processing document: 21
# [DEBUG] Tokens before processing: 66
# [DEBUG] Tokens after stop-word removal: 39
# [DEBUG] Final tokens: 39
#
# [DEBUG] Processing document: 22
# [DEBUG] Tokens before processing: 94
# [DEBUG] Tokens after stop-word removal: 59
# [DEBUG] Final tokens: 59
#
# [DEBUG] Processing document: 23
# [DEBUG] Tokens before processing: 156
# [DEBUG] Tokens after stop-word removal: 83
# [DEBUG] Final tokens: 83
#
# [DEBUG] Processing document: 24
# [DEBUG] Tokens before processing: 272
# [DEBUG] Tokens after stop-word removal: 148
# [DEBUG] Final tokens: 148
#
# [DEBUG] Processing document: 25
# [DEBUG] Tokens before processing: 385
# [DEBUG] Tokens after stop-word removal: 213
# [DEBUG] Final tokens: 213
#
# [DEBUG] Processing document: 26
# [DEBUG] Tokens before processing: 68
# [DEBUG] Tokens after stop-word removal: 38
# [DEBUG] Final tokens: 38
#
# [DEBUG] Processing document: 27
# [DEBUG] Tokens before processing: 140
# [DEBUG] Tokens after stop-word removal: 73
# [DEBUG] Final tokens: 73
#
# [DEBUG] Processing document: 28
# [DEBUG] Tokens before processing: 174
# [DEBUG] Tokens after stop-word removal: 82
# [DEBUG] Final tokens: 82
#
# [DEBUG] Processing document: 29
# [DEBUG] Tokens before processing: 260
# [DEBUG] Tokens after stop-word removal: 146
# [DEBUG] Final tokens: 146
#
# [DEBUG] Processing document: 30
# [DEBUG] Tokens before processing: 125
# [DEBUG] Tokens after stop-word removal: 76
# [DEBUG] Final tokens: 76
#
# [DEBUG] Processing document: 31
# [DEBUG] Tokens before processing: 40
# [DEBUG] Tokens after stop-word removal: 28
# [DEBUG] Final tokens: 28
#
# [DEBUG] Processing document: 32
# [DEBUG] Tokens before processing: 187
# [DEBUG] Tokens after stop-word removal: 99
# [DEBUG] Final tokens: 99
#
# [DEBUG] Processing document: 33
# [DEBUG] Tokens before processing: 274
# [DEBUG] Tokens after stop-word removal: 152
# [DEBUG] Final tokens: 152
#
# [DEBUG] Processing document: 34
# [DEBUG] Tokens before processing: 184
# [DEBUG] Tokens after stop-word removal: 112
# [DEBUG] Final tokens: 112
#
# [DEBUG] Processing document: 35
# [DEBUG] Tokens before processing: 158
# [DEBUG] Tokens after stop-word removal: 89
# [DEBUG] Final tokens: 89
#
# [DEBUG] Processing document: 36
# [DEBUG] Tokens before processing: 144
# [DEBUG] Tokens after stop-word removal: 74
# [DEBUG] Final tokens: 74
#
# [DEBUG] Processing document: 37
# [DEBUG] Tokens before processing: 175
# [DEBUG] Tokens after stop-word removal: 103
# [DEBUG] Final tokens: 103
#
# [DEBUG] Processing document: 38
# [DEBUG] Tokens before processing: 91
# [DEBUG] Tokens after stop-word removal: 54
# [DEBUG] Final tokens: 54
#
# [DEBUG] Processing document: 39
# [DEBUG] Tokens before processing: 171
# [DEBUG] Tokens after stop-word removal: 87
# [DEBUG] Final tokens: 87
#
# [DEBUG] Processing document: 40
# [DEBUG] Tokens before processing: 160
# [DEBUG] Tokens after stop-word removal: 99
# [DEBUG] Final tokens: 99
#
# [DEBUG] Processing document: 41
# [DEBUG] Tokens before processing: 77
# [DEBUG] Tokens after stop-word removal: 45
# [DEBUG] Final tokens: 45
#
# [DEBUG] Processing document: 42
# [DEBUG] Tokens before processing: 276
# [DEBUG] Tokens after stop-word removal: 145
# [DEBUG] Final tokens: 145
#
# [DEBUG] Processing document: 43
# [DEBUG] Tokens before processing: 161
# [DEBUG] Tokens after stop-word removal: 86
# [DEBUG] Final tokens: 86
#
# [DEBUG] Processing document: 44
# [DEBUG] Tokens before processing: 289
# [DEBUG] Tokens after stop-word removal: 157
# [DEBUG] Final tokens: 157
#
# [DEBUG] Processing document: 45
# [DEBUG] Tokens before processing: 175
# [DEBUG] Tokens after stop-word removal: 96
# [DEBUG] Final tokens: 96
#
# [DEBUG] Processing document: 46
# [DEBUG] Tokens before processing: 95
# [DEBUG] Tokens after stop-word removal: 45
# [DEBUG] Final tokens: 45
#
# [DEBUG] Processing document: 47
# [DEBUG] Tokens before processing: 206
# [DEBUG] Tokens after stop-word removal: 124
# [DEBUG] Final tokens: 124
#
# [DEBUG] Processing document: 48
# [DEBUG] Tokens before processing: 133
# [DEBUG] Tokens after stop-word removal: 70
# [DEBUG] Final tokens: 70
#
# [DEBUG] Processing document: 49
# [DEBUG] Tokens before processing: 409
# [DEBUG] Tokens after stop-word removal: 219
# [DEBUG] Final tokens: 219
#
# [DEBUG] Processing document: 50
# [DEBUG] Tokens before processing: 162
# [DEBUG] Tokens after stop-word removal: 99
# [DEBUG] Final tokens: 99
#
# [DEBUG] Processing document: 51
# [DEBUG] Tokens before processing: 213
# [DEBUG] Tokens after stop-word removal: 110
# [DEBUG] Final tokens: 110
#
# [DEBUG] Processing document: 52
# [DEBUG] Tokens before processing: 192
# [DEBUG] Tokens after stop-word removal: 105
# [DEBUG] Final tokens: 105
#
# [DEBUG] Processing document: 53
# [DEBUG] Tokens before processing: 210
# [DEBUG] Tokens after stop-word removal: 127
# [DEBUG] Final tokens: 127
#
# [DEBUG] Processing document: 54
# [DEBUG] Tokens before processing: 233
# [DEBUG] Tokens after stop-word removal: 141
# [DEBUG] Final tokens: 141
#
# [DEBUG] Processing document: 55
# [DEBUG] Tokens before processing: 155
# [DEBUG] Tokens after stop-word removal: 89
# [DEBUG] Final tokens: 89
#
# [DEBUG] Processing document: 56
# [DEBUG] Tokens before processing: 238
# [DEBUG] Tokens after stop-word removal: 127
# [DEBUG] Final tokens: 127
#
# [DEBUG] Processing document: 57
# [DEBUG] Tokens before processing: 192
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 58
# [DEBUG] Tokens before processing: 187
# [DEBUG] Tokens after stop-word removal: 102
# [DEBUG] Final tokens: 102
#
# [DEBUG] Processing document: 59
# [DEBUG] Tokens before processing: 245
# [DEBUG] Tokens after stop-word removal: 143
# [DEBUG] Final tokens: 143
#
# [DEBUG] Processing document: 60
# [DEBUG] Tokens before processing: 156
# [DEBUG] Tokens after stop-word removal: 89
# [DEBUG] Final tokens: 89
#
# [DEBUG] Processing document: 61
# [DEBUG] Tokens before processing: 150
# [DEBUG] Tokens after stop-word removal: 77
# [DEBUG] Final tokens: 77
#
# [DEBUG] Processing document: 62
# [DEBUG] Tokens before processing: 296
# [DEBUG] Tokens after stop-word removal: 171
# [DEBUG] Final tokens: 171
#
# [DEBUG] Processing document: 63
# [DEBUG] Tokens before processing: 139
# [DEBUG] Tokens after stop-word removal: 83
# [DEBUG] Final tokens: 83
#
# [DEBUG] Processing document: 64
# [DEBUG] Tokens before processing: 149
# [DEBUG] Tokens after stop-word removal: 87
# [DEBUG] Final tokens: 87
#
# [DEBUG] Processing document: 65
# [DEBUG] Tokens before processing: 91
# [DEBUG] Tokens after stop-word removal: 54
# [DEBUG] Final tokens: 54
#
# [DEBUG] Processing document: 66
# [DEBUG] Tokens before processing: 183
# [DEBUG] Tokens after stop-word removal: 119
# [DEBUG] Final tokens: 119
#
# [DEBUG] Processing document: 67
# [DEBUG] Tokens before processing: 98
# [DEBUG] Tokens after stop-word removal: 50
# [DEBUG] Final tokens: 50
#
# [DEBUG] Processing document: 68
# [DEBUG] Tokens before processing: 120
# [DEBUG] Tokens after stop-word removal: 68
# [DEBUG] Final tokens: 68
#
# [DEBUG] Processing document: 69
# [DEBUG] Tokens before processing: 143
# [DEBUG] Tokens after stop-word removal: 84
# [DEBUG] Final tokens: 84
#
# [DEBUG] Processing document: 70
# [DEBUG] Tokens before processing: 222
# [DEBUG] Tokens after stop-word removal: 127
# [DEBUG] Final tokens: 127
#
# [DEBUG] Processing document: 71
# [DEBUG] Tokens before processing: 88
# [DEBUG] Tokens after stop-word removal: 56
# [DEBUG] Final tokens: 56
#
# [DEBUG] Processing document: 72
# [DEBUG] Tokens before processing: 268
# [DEBUG] Tokens after stop-word removal: 157
# [DEBUG] Final tokens: 157
#
# [DEBUG] Processing document: 73
# [DEBUG] Tokens before processing: 345
# [DEBUG] Tokens after stop-word removal: 170
# [DEBUG] Final tokens: 170
#
# [DEBUG] Processing document: 74
# [DEBUG] Tokens before processing: 94
# [DEBUG] Tokens after stop-word removal: 56
# [DEBUG] Final tokens: 56
#
# [DEBUG] Processing document: 75
# [DEBUG] Tokens before processing: 119
# [DEBUG] Tokens after stop-word removal: 60
# [DEBUG] Final tokens: 60
#
# [DEBUG] Processing document: 76
# [DEBUG] Tokens before processing: 211
# [DEBUG] Tokens after stop-word removal: 127
# [DEBUG] Final tokens: 127
#
# [DEBUG] Processing document: 77
# [DEBUG] Tokens before processing: 355
# [DEBUG] Tokens after stop-word removal: 187
# [DEBUG] Final tokens: 187
#
# [DEBUG] Processing document: 78
# [DEBUG] Tokens before processing: 204
# [DEBUG] Tokens after stop-word removal: 115
# [DEBUG] Final tokens: 115
#
# [DEBUG] Processing document: 79
# [DEBUG] Tokens before processing: 167
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 80
# [DEBUG] Tokens before processing: 309
# [DEBUG] Tokens after stop-word removal: 173
# [DEBUG] Final tokens: 173
#
# [DEBUG] Processing document: 81
# [DEBUG] Tokens before processing: 126
# [DEBUG] Tokens after stop-word removal: 74
# [DEBUG] Final tokens: 74
#
# [DEBUG] Processing document: 82
# [DEBUG] Tokens before processing: 334
# [DEBUG] Tokens after stop-word removal: 186
# [DEBUG] Final tokens: 186
#
# [DEBUG] Processing document: 83
# [DEBUG] Tokens before processing: 307
# [DEBUG] Tokens after stop-word removal: 154
# [DEBUG] Final tokens: 154
#
# [DEBUG] Processing document: 84
# [DEBUG] Tokens before processing: 179
# [DEBUG] Tokens after stop-word removal: 102
# [DEBUG] Final tokens: 102
#
# [DEBUG] Processing document: 85
# [DEBUG] Tokens before processing: 290
# [DEBUG] Tokens after stop-word removal: 152
# [DEBUG] Final tokens: 152
#
# [DEBUG] Processing document: 86
# [DEBUG] Tokens before processing: 125
# [DEBUG] Tokens after stop-word removal: 80
# [DEBUG] Final tokens: 80
#
# [DEBUG] Processing document: 87
# [DEBUG] Tokens before processing: 123
# [DEBUG] Tokens after stop-word removal: 71
# [DEBUG] Final tokens: 71
#
# [DEBUG] Processing document: 88
# [DEBUG] Tokens before processing: 148
# [DEBUG] Tokens after stop-word removal: 89
# [DEBUG] Final tokens: 89
#
# [DEBUG] Processing document: 89
# [DEBUG] Tokens before processing: 439
# [DEBUG] Tokens after stop-word removal: 220
# [DEBUG] Final tokens: 220
#
# [DEBUG] Processing document: 90
# [DEBUG] Tokens before processing: 113
# [DEBUG] Tokens after stop-word removal: 62
# [DEBUG] Final tokens: 62
#
# [DEBUG] Processing document: 91
# [DEBUG] Tokens before processing: 166
# [DEBUG] Tokens after stop-word removal: 86
# [DEBUG] Final tokens: 86
#
# [DEBUG] Processing document: 92
# [DEBUG] Tokens before processing: 211
# [DEBUG] Tokens after stop-word removal: 125
# [DEBUG] Final tokens: 125
#
# [DEBUG] Processing document: 93
# [DEBUG] Tokens before processing: 96
# [DEBUG] Tokens after stop-word removal: 58
# [DEBUG] Final tokens: 58
#
# [DEBUG] Processing document: 94
# [DEBUG] Tokens before processing: 481
# [DEBUG] Tokens after stop-word removal: 239
# [DEBUG] Final tokens: 239
#
# [DEBUG] Processing document: 95
# [DEBUG] Tokens before processing: 126
# [DEBUG] Tokens after stop-word removal: 64
# [DEBUG] Final tokens: 64
#
# [DEBUG] Processing document: 96
# [DEBUG] Tokens before processing: 279
# [DEBUG] Tokens after stop-word removal: 144
# [DEBUG] Final tokens: 144
#
# [DEBUG] Processing document: 97
# [DEBUG] Tokens before processing: 245
# [DEBUG] Tokens after stop-word removal: 138
# [DEBUG] Final tokens: 138
#
# [DEBUG] Processing document: 98
# [DEBUG] Tokens before processing: 77
# [DEBUG] Tokens after stop-word removal: 45
# [DEBUG] Final tokens: 45
#
# [DEBUG] Processing document: 99
# [DEBUG] Tokens before processing: 306
# [DEBUG] Tokens after stop-word removal: 160
# [DEBUG] Final tokens: 160
#
# [DEBUG] Processing document: 100
# [DEBUG] Tokens before processing: 233
# [DEBUG] Tokens after stop-word removal: 122
# [DEBUG] Final tokens: 122
#
# [DEBUG] Processing document: 101
# [DEBUG] Tokens before processing: 334
# [DEBUG] Tokens after stop-word removal: 188
# [DEBUG] Final tokens: 188
#
# [DEBUG] Processing document: 102
# [DEBUG] Tokens before processing: 80
# [DEBUG] Tokens after stop-word removal: 45
# [DEBUG] Final tokens: 45
#
# [DEBUG] Processing document: 103
# [DEBUG] Tokens before processing: 137
# [DEBUG] Tokens after stop-word removal: 74
# [DEBUG] Final tokens: 74
#
# [DEBUG] Processing document: 104
# [DEBUG] Tokens before processing: 134
# [DEBUG] Tokens after stop-word removal: 74
# [DEBUG] Final tokens: 74
#
# [DEBUG] Processing document: 105
# [DEBUG] Tokens before processing: 183
# [DEBUG] Tokens after stop-word removal: 92
# [DEBUG] Final tokens: 92
#
# [DEBUG] Processing document: 106
# [DEBUG] Tokens before processing: 76
# [DEBUG] Tokens after stop-word removal: 42
# [DEBUG] Final tokens: 42
#
# [DEBUG] Processing document: 107
# [DEBUG] Tokens before processing: 96
# [DEBUG] Tokens after stop-word removal: 51
# [DEBUG] Final tokens: 51
#
# [DEBUG] Processing document: 108
# [DEBUG] Tokens before processing: 114
# [DEBUG] Tokens after stop-word removal: 60
# [DEBUG] Final tokens: 60
#
# [DEBUG] Processing document: 109
# [DEBUG] Tokens before processing: 181
# [DEBUG] Tokens after stop-word removal: 94
# [DEBUG] Final tokens: 94
#
# [DEBUG] Processing document: 110
# [DEBUG] Tokens before processing: 334
# [DEBUG] Tokens after stop-word removal: 180
# [DEBUG] Final tokens: 180
#
# [DEBUG] Processing document: 111
# [DEBUG] Tokens before processing: 124
# [DEBUG] Tokens after stop-word removal: 64
# [DEBUG] Final tokens: 64
#
# [DEBUG] Processing document: 112
# [DEBUG] Tokens before processing: 153
# [DEBUG] Tokens after stop-word removal: 90
# [DEBUG] Final tokens: 90
#
# [DEBUG] Processing document: 113
# [DEBUG] Tokens before processing: 116
# [DEBUG] Tokens after stop-word removal: 63
# [DEBUG] Final tokens: 63
#
# [DEBUG] Processing document: 114
# [DEBUG] Tokens before processing: 202
# [DEBUG] Tokens after stop-word removal: 99
# [DEBUG] Final tokens: 99
#
# [DEBUG] Processing document: 115
# [DEBUG] Tokens before processing: 193
# [DEBUG] Tokens after stop-word removal: 109
# [DEBUG] Final tokens: 109
#
# [DEBUG] Processing document: 116
# [DEBUG] Tokens before processing: 171
# [DEBUG] Tokens after stop-word removal: 95
# [DEBUG] Final tokens: 95
#
# [DEBUG] Processing document: 117
# [DEBUG] Tokens before processing: 143
# [DEBUG] Tokens after stop-word removal: 76
# [DEBUG] Final tokens: 76
#
# [DEBUG] Processing document: 118
# [DEBUG] Tokens before processing: 158
# [DEBUG] Tokens after stop-word removal: 87
# [DEBUG] Final tokens: 87
#
# [DEBUG] Processing document: 119
# [DEBUG] Tokens before processing: 87
# [DEBUG] Tokens after stop-word removal: 49
# [DEBUG] Final tokens: 49
#
# [DEBUG] Processing document: 120
# [DEBUG] Tokens before processing: 114
# [DEBUG] Tokens after stop-word removal: 68
# [DEBUG] Final tokens: 68
#
# [DEBUG] Processing document: 121
# [DEBUG] Tokens before processing: 147
# [DEBUG] Tokens after stop-word removal: 80
# [DEBUG] Final tokens: 80
#
# [DEBUG] Processing document: 122
# [DEBUG] Tokens before processing: 246
# [DEBUG] Tokens after stop-word removal: 138
# [DEBUG] Final tokens: 138
#
# [DEBUG] Processing document: 123
# [DEBUG] Tokens before processing: 249
# [DEBUG] Tokens after stop-word removal: 134
# [DEBUG] Final tokens: 134
#
# [DEBUG] Processing document: 124
# [DEBUG] Tokens before processing: 225
# [DEBUG] Tokens after stop-word removal: 125
# [DEBUG] Final tokens: 125
#
# [DEBUG] Processing document: 125
# [DEBUG] Tokens before processing: 227
# [DEBUG] Tokens after stop-word removal: 134
# [DEBUG] Final tokens: 134
#
# [DEBUG] Processing document: 126
# [DEBUG] Tokens before processing: 129
# [DEBUG] Tokens after stop-word removal: 74
# [DEBUG] Final tokens: 74
#
# [DEBUG] Processing document: 127
# [DEBUG] Tokens before processing: 127
# [DEBUG] Tokens after stop-word removal: 66
# [DEBUG] Final tokens: 66
#
# [DEBUG] Processing document: 128
# [DEBUG] Tokens before processing: 171
# [DEBUG] Tokens after stop-word removal: 105
# [DEBUG] Final tokens: 105
#
# [DEBUG] Processing document: 129
# [DEBUG] Tokens before processing: 254
# [DEBUG] Tokens after stop-word removal: 139
# [DEBUG] Final tokens: 139
#
# [DEBUG] Processing document: 130
# [DEBUG] Tokens before processing: 95
# [DEBUG] Tokens after stop-word removal: 42
# [DEBUG] Final tokens: 42
#
# [DEBUG] Processing document: 131
# [DEBUG] Tokens before processing: 369
# [DEBUG] Tokens after stop-word removal: 169
# [DEBUG] Final tokens: 169
#
# [DEBUG] Processing document: 132
# [DEBUG] Tokens before processing: 352
# [DEBUG] Tokens after stop-word removal: 172
# [DEBUG] Final tokens: 172
#
# [DEBUG] Processing document: 133
# [DEBUG] Tokens before processing: 223
# [DEBUG] Tokens after stop-word removal: 115
# [DEBUG] Final tokens: 115
#
# [DEBUG] Processing document: 134
# [DEBUG] Tokens before processing: 215
# [DEBUG] Tokens after stop-word removal: 105
# [DEBUG] Final tokens: 105
#
# [DEBUG] Processing document: 135
# [DEBUG] Tokens before processing: 204
# [DEBUG] Tokens after stop-word removal: 105
# [DEBUG] Final tokens: 105
#
# [DEBUG] Processing document: 136
# [DEBUG] Tokens before processing: 93
# [DEBUG] Tokens after stop-word removal: 59
# [DEBUG] Final tokens: 59
#
# [DEBUG] Processing document: 137
# [DEBUG] Tokens before processing: 52
# [DEBUG] Tokens after stop-word removal: 28
# [DEBUG] Final tokens: 28
#
# [DEBUG] Processing document: 138
# [DEBUG] Tokens before processing: 232
# [DEBUG] Tokens after stop-word removal: 116
# [DEBUG] Final tokens: 116
#
# [DEBUG] Processing document: 139
# [DEBUG] Tokens before processing: 147
# [DEBUG] Tokens after stop-word removal: 73
# [DEBUG] Final tokens: 73
#
# [DEBUG] Processing document: 140
# [DEBUG] Tokens before processing: 370
# [DEBUG] Tokens after stop-word removal: 188
# [DEBUG] Final tokens: 188
#
# [DEBUG] Processing document: 141
# [DEBUG] Tokens before processing: 95
# [DEBUG] Tokens after stop-word removal: 67
# [DEBUG] Final tokens: 67
#
# [DEBUG] Processing document: 142
# [DEBUG] Tokens before processing: 107
# [DEBUG] Tokens after stop-word removal: 72
# [DEBUG] Final tokens: 72
#
# [DEBUG] Processing document: 143
# [DEBUG] Tokens before processing: 62
# [DEBUG] Tokens after stop-word removal: 32
# [DEBUG] Final tokens: 32
#
# [DEBUG] Processing document: 144
# [DEBUG] Tokens before processing: 143
# [DEBUG] Tokens after stop-word removal: 82
# [DEBUG] Final tokens: 82
#
# [DEBUG] Processing document: 145
# [DEBUG] Tokens before processing: 144
# [DEBUG] Tokens after stop-word removal: 75
# [DEBUG] Final tokens: 75
#
# [DEBUG] Processing document: 146
# [DEBUG] Tokens before processing: 248
# [DEBUG] Tokens after stop-word removal: 132
# [DEBUG] Final tokens: 132
#
# [DEBUG] Processing document: 147
# [DEBUG] Tokens before processing: 173
# [DEBUG] Tokens after stop-word removal: 106
# [DEBUG] Final tokens: 106
#
# [DEBUG] Processing document: 148
# [DEBUG] Tokens before processing: 147
# [DEBUG] Tokens after stop-word removal: 79
# [DEBUG] Final tokens: 79
#
# [DEBUG] Processing document: 149
# [DEBUG] Tokens before processing: 292
# [DEBUG] Tokens after stop-word removal: 145
# [DEBUG] Final tokens: 145
#
# [DEBUG] Processing document: 150
# [DEBUG] Tokens before processing: 180
# [DEBUG] Tokens after stop-word removal: 99
# [DEBUG] Final tokens: 99
#
# [DEBUG] Processing document: 151
# [DEBUG] Tokens before processing: 307
# [DEBUG] Tokens after stop-word removal: 148
# [DEBUG] Final tokens: 148
#
# [DEBUG] Processing document: 152
# [DEBUG] Tokens before processing: 195
# [DEBUG] Tokens after stop-word removal: 87
# [DEBUG] Final tokens: 87
#
# [DEBUG] Processing document: 153
# [DEBUG] Tokens before processing: 76
# [DEBUG] Tokens after stop-word removal: 39
# [DEBUG] Final tokens: 39
#
# [DEBUG] Processing document: 154
# [DEBUG] Tokens before processing: 97
# [DEBUG] Tokens after stop-word removal: 54
# [DEBUG] Final tokens: 54
#
# [DEBUG] Processing document: 155
# [DEBUG] Tokens before processing: 271
# [DEBUG] Tokens after stop-word removal: 129
# [DEBUG] Final tokens: 129
#
# [DEBUG] Processing document: 156
# [DEBUG] Tokens before processing: 274
# [DEBUG] Tokens after stop-word removal: 126
# [DEBUG] Final tokens: 126
#
# [DEBUG] Processing document: 157
# [DEBUG] Tokens before processing: 250
# [DEBUG] Tokens after stop-word removal: 121
# [DEBUG] Final tokens: 121
#
# [DEBUG] Processing document: 158
# [DEBUG] Tokens before processing: 147
# [DEBUG] Tokens after stop-word removal: 80
# [DEBUG] Final tokens: 80
#
# [DEBUG] Processing document: 159
# [DEBUG] Tokens before processing: 107
# [DEBUG] Tokens after stop-word removal: 59
# [DEBUG] Final tokens: 59
#
# [DEBUG] Processing document: 160
# [DEBUG] Tokens before processing: 387
# [DEBUG] Tokens after stop-word removal: 212
# [DEBUG] Final tokens: 212
#
# [DEBUG] Processing document: 161
# [DEBUG] Tokens before processing: 59
# [DEBUG] Tokens after stop-word removal: 36
# [DEBUG] Final tokens: 36
#
# [DEBUG] Processing document: 162
# [DEBUG] Tokens before processing: 202
# [DEBUG] Tokens after stop-word removal: 111
# [DEBUG] Final tokens: 111
#
# [DEBUG] Processing document: 163
# [DEBUG] Tokens before processing: 388
# [DEBUG] Tokens after stop-word removal: 238
# [DEBUG] Final tokens: 238
#
# [DEBUG] Processing document: 164
# [DEBUG] Tokens before processing: 300
# [DEBUG] Tokens after stop-word removal: 182
# [DEBUG] Final tokens: 182
#
# [DEBUG] Processing document: 165
# [DEBUG] Tokens before processing: 380
# [DEBUG] Tokens after stop-word removal: 217
# [DEBUG] Final tokens: 217
#
# [DEBUG] Processing document: 166
# [DEBUG] Tokens before processing: 198
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 167
# [DEBUG] Tokens before processing: 131
# [DEBUG] Tokens after stop-word removal: 70
# [DEBUG] Final tokens: 70
#
# [DEBUG] Processing document: 168
# [DEBUG] Tokens before processing: 258
# [DEBUG] Tokens after stop-word removal: 133
# [DEBUG] Final tokens: 133
#
# [DEBUG] Processing document: 169
# [DEBUG] Tokens before processing: 143
# [DEBUG] Tokens after stop-word removal: 76
# [DEBUG] Final tokens: 76
#
# [DEBUG] Processing document: 170
# [DEBUG] Tokens before processing: 268
# [DEBUG] Tokens after stop-word removal: 133
# [DEBUG] Final tokens: 133
#
# [DEBUG] Processing document: 171
# [DEBUG] Tokens before processing: 181
# [DEBUG] Tokens after stop-word removal: 105
# [DEBUG] Final tokens: 105
#
# [DEBUG] Processing document: 172
# [DEBUG] Tokens before processing: 235
# [DEBUG] Tokens after stop-word removal: 128
# [DEBUG] Final tokens: 128
#
# [DEBUG] Processing document: 173
# [DEBUG] Tokens before processing: 316
# [DEBUG] Tokens after stop-word removal: 181
# [DEBUG] Final tokens: 181
#
# [DEBUG] Processing document: 174
# [DEBUG] Tokens before processing: 306
# [DEBUG] Tokens after stop-word removal: 177
# [DEBUG] Final tokens: 177
#
# [DEBUG] Processing document: 175
# [DEBUG] Tokens before processing: 77
# [DEBUG] Tokens after stop-word removal: 34
# [DEBUG] Final tokens: 34
#
# [DEBUG] Processing document: 176
# [DEBUG] Tokens before processing: 122
# [DEBUG] Tokens after stop-word removal: 68
# [DEBUG] Final tokens: 68
#
# [DEBUG] Processing document: 177
# [DEBUG] Tokens before processing: 231
# [DEBUG] Tokens after stop-word removal: 115
# [DEBUG] Final tokens: 115
#
# [DEBUG] Processing document: 178
# [DEBUG] Tokens before processing: 77
# [DEBUG] Tokens after stop-word removal: 40
# [DEBUG] Final tokens: 40
#
# [DEBUG] Processing document: 179
# [DEBUG] Tokens before processing: 280
# [DEBUG] Tokens after stop-word removal: 149
# [DEBUG] Final tokens: 149
#
# [DEBUG] Processing document: 180
# [DEBUG] Tokens before processing: 73
# [DEBUG] Tokens after stop-word removal: 41
# [DEBUG] Final tokens: 41
#
# [DEBUG] Processing document: 181
# [DEBUG] Tokens before processing: 55
# [DEBUG] Tokens after stop-word removal: 36
# [DEBUG] Final tokens: 36
#
# [DEBUG] Processing document: 182
# [DEBUG] Tokens before processing: 122
# [DEBUG] Tokens after stop-word removal: 68
# [DEBUG] Final tokens: 68
#
# [DEBUG] Processing document: 183
# [DEBUG] Tokens before processing: 156
# [DEBUG] Tokens after stop-word removal: 89
# [DEBUG] Final tokens: 89
#
# [DEBUG] Processing document: 184
# [DEBUG] Tokens before processing: 151
# [DEBUG] Tokens after stop-word removal: 84
# [DEBUG] Final tokens: 84
#
# [DEBUG] Processing document: 185
# [DEBUG] Tokens before processing: 306
# [DEBUG] Tokens after stop-word removal: 172
# [DEBUG] Final tokens: 172
#
# [DEBUG] Processing document: 186
# [DEBUG] Tokens before processing: 192
# [DEBUG] Tokens after stop-word removal: 100
# [DEBUG] Final tokens: 100
#
# [DEBUG] Processing document: 187
# [DEBUG] Tokens before processing: 285
# [DEBUG] Tokens after stop-word removal: 169
# [DEBUG] Final tokens: 169
#
# [DEBUG] Processing document: 188
# [DEBUG] Tokens before processing: 247
# [DEBUG] Tokens after stop-word removal: 133
# [DEBUG] Final tokens: 133
#
# [DEBUG] Processing document: 189
# [DEBUG] Tokens before processing: 348
# [DEBUG] Tokens after stop-word removal: 210
# [DEBUG] Final tokens: 210
#
# [DEBUG] Processing document: 190
# [DEBUG] Tokens before processing: 165
# [DEBUG] Tokens after stop-word removal: 84
# [DEBUG] Final tokens: 84
#
# [DEBUG] Processing document: 191
# [DEBUG] Tokens before processing: 215
# [DEBUG] Tokens after stop-word removal: 111
# [DEBUG] Final tokens: 111
#
# [DEBUG] Processing document: 192
# [DEBUG] Tokens before processing: 212
# [DEBUG] Tokens after stop-word removal: 105
# [DEBUG] Final tokens: 105
#
# [DEBUG] Processing document: 193
# [DEBUG] Tokens before processing: 410
# [DEBUG] Tokens after stop-word removal: 217
# [DEBUG] Final tokens: 217
#
# [DEBUG] Processing document: 194
# [DEBUG] Tokens before processing: 75
# [DEBUG] Tokens after stop-word removal: 42
# [DEBUG] Final tokens: 42
#
# [DEBUG] Processing document: 195
# [DEBUG] Tokens before processing: 182
# [DEBUG] Tokens after stop-word removal: 107
# [DEBUG] Final tokens: 107
#
# [DEBUG] Processing document: 196
# [DEBUG] Tokens before processing: 180
# [DEBUG] Tokens after stop-word removal: 88
# [DEBUG] Final tokens: 88
#
# [DEBUG] Processing document: 197
# [DEBUG] Tokens before processing: 281
# [DEBUG] Tokens after stop-word removal: 147
# [DEBUG] Final tokens: 147
#
# [DEBUG] Processing document: 198
# [DEBUG] Tokens before processing: 293
# [DEBUG] Tokens after stop-word removal: 166
# [DEBUG] Final tokens: 166
#
# [DEBUG] Processing document: 199
# [DEBUG] Tokens before processing: 359
# [DEBUG] Tokens after stop-word removal: 199
# [DEBUG] Final tokens: 199
#
# [DEBUG] Processing document: 200
# [DEBUG] Tokens before processing: 129
# [DEBUG] Tokens after stop-word removal: 78
# [DEBUG] Final tokens: 78
#
# [DEBUG] Processing document: 201
# [DEBUG] Tokens before processing: 191
# [DEBUG] Tokens after stop-word removal: 117
# [DEBUG] Final tokens: 117
#
# [DEBUG] Processing document: 202
# [DEBUG] Tokens before processing: 302
# [DEBUG] Tokens after stop-word removal: 149
# [DEBUG] Final tokens: 149
#
# [DEBUG] Processing document: 203
# [DEBUG] Tokens before processing: 79
# [DEBUG] Tokens after stop-word removal: 47
# [DEBUG] Final tokens: 47
#
# [DEBUG] Processing document: 204
# [DEBUG] Tokens before processing: 201
# [DEBUG] Tokens after stop-word removal: 114
# [DEBUG] Final tokens: 114
#
# [DEBUG] Processing document: 205
# [DEBUG] Tokens before processing: 276
# [DEBUG] Tokens after stop-word removal: 163
# [DEBUG] Final tokens: 163
#
# [DEBUG] Processing document: 206
# [DEBUG] Tokens before processing: 306
# [DEBUG] Tokens after stop-word removal: 148
# [DEBUG] Final tokens: 148
#
# [DEBUG] Processing document: 207
# [DEBUG] Tokens before processing: 213
# [DEBUG] Tokens after stop-word removal: 99
# [DEBUG] Final tokens: 99
#
# [DEBUG] Processing document: 208
# [DEBUG] Tokens before processing: 136
# [DEBUG] Tokens after stop-word removal: 79
# [DEBUG] Final tokens: 79
#
# [DEBUG] Processing document: 209
# [DEBUG] Tokens before processing: 236
# [DEBUG] Tokens after stop-word removal: 142
# [DEBUG] Final tokens: 142
#
# [DEBUG] Processing document: 210
# [DEBUG] Tokens before processing: 338
# [DEBUG] Tokens after stop-word removal: 160
# [DEBUG] Final tokens: 160
#
# [DEBUG] Processing document: 211
# [DEBUG] Tokens before processing: 227
# [DEBUG] Tokens after stop-word removal: 116
# [DEBUG] Final tokens: 116
#
# [DEBUG] Processing document: 212
# [DEBUG] Tokens before processing: 354
# [DEBUG] Tokens after stop-word removal: 186
# [DEBUG] Final tokens: 186
#
# [DEBUG] Processing document: 213
# [DEBUG] Tokens before processing: 261
# [DEBUG] Tokens after stop-word removal: 146
# [DEBUG] Final tokens: 146
#
# [DEBUG] Processing document: 214
# [DEBUG] Tokens before processing: 143
# [DEBUG] Tokens after stop-word removal: 71
# [DEBUG] Final tokens: 71
#
# [DEBUG] Processing document: 215
# [DEBUG] Tokens before processing: 89
# [DEBUG] Tokens after stop-word removal: 55
# [DEBUG] Final tokens: 55
#
# [DEBUG] Processing document: 216
# [DEBUG] Tokens before processing: 274
# [DEBUG] Tokens after stop-word removal: 146
# [DEBUG] Final tokens: 146
#
# [DEBUG] Processing document: 217
# [DEBUG] Tokens before processing: 127
# [DEBUG] Tokens after stop-word removal: 67
# [DEBUG] Final tokens: 67
#
# [DEBUG] Processing document: 218
# [DEBUG] Tokens before processing: 261
# [DEBUG] Tokens after stop-word removal: 138
# [DEBUG] Final tokens: 138
#
# [DEBUG] Processing document: 219
# [DEBUG] Tokens before processing: 227
# [DEBUG] Tokens after stop-word removal: 118
# [DEBUG] Final tokens: 118
#
# [DEBUG] Processing document: 220
# [DEBUG] Tokens before processing: 161
# [DEBUG] Tokens after stop-word removal: 82
# [DEBUG] Final tokens: 82
#
# [DEBUG] Processing document: 221
# [DEBUG] Tokens before processing: 169
# [DEBUG] Tokens after stop-word removal: 96
# [DEBUG] Final tokens: 96
#
# [DEBUG] Processing document: 222
# [DEBUG] Tokens before processing: 204
# [DEBUG] Tokens after stop-word removal: 113
# [DEBUG] Final tokens: 113
#
# [DEBUG] Processing document: 223
# [DEBUG] Tokens before processing: 50
# [DEBUG] Tokens after stop-word removal: 27
# [DEBUG] Final tokens: 27
#
# [DEBUG] Processing document: 224
# [DEBUG] Tokens before processing: 80
# [DEBUG] Tokens after stop-word removal: 48
# [DEBUG] Final tokens: 48
#
# [DEBUG] Processing document: 225
# [DEBUG] Tokens before processing: 375
# [DEBUG] Tokens after stop-word removal: 212
# [DEBUG] Final tokens: 212
#
# [DEBUG] Processing document: 226
# [DEBUG] Tokens before processing: 80
# [DEBUG] Tokens after stop-word removal: 47
# [DEBUG] Final tokens: 47
#
# [DEBUG] Processing document: 227
# [DEBUG] Tokens before processing: 173
# [DEBUG] Tokens after stop-word removal: 95
# [DEBUG] Final tokens: 95
#
# [DEBUG] Processing document: 228
# [DEBUG] Tokens before processing: 122
# [DEBUG] Tokens after stop-word removal: 59
# [DEBUG] Final tokens: 59
#
# [DEBUG] Processing document: 229
# [DEBUG] Tokens before processing: 246
# [DEBUG] Tokens after stop-word removal: 133
# [DEBUG] Final tokens: 133
#
# [DEBUG] Processing document: 230
# [DEBUG] Tokens before processing: 232
# [DEBUG] Tokens after stop-word removal: 125
# [DEBUG] Final tokens: 125
#
# [DEBUG] Processing document: 231
# [DEBUG] Tokens before processing: 112
# [DEBUG] Tokens after stop-word removal: 68
# [DEBUG] Final tokens: 68
#
# [DEBUG] Processing document: 232
# [DEBUG] Tokens before processing: 247
# [DEBUG] Tokens after stop-word removal: 153
# [DEBUG] Final tokens: 153
#
# [DEBUG] Processing document: 233
# [DEBUG] Tokens before processing: 121
# [DEBUG] Tokens after stop-word removal: 62
# [DEBUG] Final tokens: 62
#
# [DEBUG] Processing document: 234
# [DEBUG] Tokens before processing: 326
# [DEBUG] Tokens after stop-word removal: 190
# [DEBUG] Final tokens: 190
#
# [DEBUG] Processing document: 235
# [DEBUG] Tokens before processing: 152
# [DEBUG] Tokens after stop-word removal: 82
# [DEBUG] Final tokens: 82
#
# [DEBUG] Processing document: 236
# [DEBUG] Tokens before processing: 174
# [DEBUG] Tokens after stop-word removal: 88
# [DEBUG] Final tokens: 88
#
# [DEBUG] Processing document: 237
# [DEBUG] Tokens before processing: 148
# [DEBUG] Tokens after stop-word removal: 81
# [DEBUG] Final tokens: 81
#
# [DEBUG] Processing document: 238
# [DEBUG] Tokens before processing: 61
# [DEBUG] Tokens after stop-word removal: 37
# [DEBUG] Final tokens: 37
#
# [DEBUG] Processing document: 239
# [DEBUG] Tokens before processing: 195
# [DEBUG] Tokens after stop-word removal: 98
# [DEBUG] Final tokens: 98
#
# [DEBUG] Processing document: 240
# [DEBUG] Tokens before processing: 106
# [DEBUG] Tokens after stop-word removal: 66
# [DEBUG] Final tokens: 66
#
# [DEBUG] Processing document: 241
# [DEBUG] Tokens before processing: 83
# [DEBUG] Tokens after stop-word removal: 47
# [DEBUG] Final tokens: 47
#
# [DEBUG] Processing document: 242
# [DEBUG] Tokens before processing: 82
# [DEBUG] Tokens after stop-word removal: 48
# [DEBUG] Final tokens: 48
#
# [DEBUG] Processing document: 243
# [DEBUG] Tokens before processing: 121
# [DEBUG] Tokens after stop-word removal: 56
# [DEBUG] Final tokens: 56
#
# [DEBUG] Processing document: 244
# [DEBUG] Tokens before processing: 499
# [DEBUG] Tokens after stop-word removal: 257
# [DEBUG] Final tokens: 257
#
# [DEBUG] Processing document: 245
# [DEBUG] Tokens before processing: 166
# [DEBUG] Tokens after stop-word removal: 79
# [DEBUG] Final tokens: 79
#
# [DEBUG] Processing document: 246
# [DEBUG] Tokens before processing: 162
# [DEBUG] Tokens after stop-word removal: 84
# [DEBUG] Final tokens: 84
#
# [DEBUG] Processing document: 247
# [DEBUG] Tokens before processing: 196
# [DEBUG] Tokens after stop-word removal: 100
# [DEBUG] Final tokens: 100
#
# [DEBUG] Processing document: 248
# [DEBUG] Tokens before processing: 142
# [DEBUG] Tokens after stop-word removal: 82
# [DEBUG] Final tokens: 82
#
# [DEBUG] Processing document: 249
# [DEBUG] Tokens before processing: 173
# [DEBUG] Tokens after stop-word removal: 81
# [DEBUG] Final tokens: 81
#
# [DEBUG] Processing document: 250
# [DEBUG] Tokens before processing: 66
# [DEBUG] Tokens after stop-word removal: 39
# [DEBUG] Final tokens: 39
#
# [DEBUG] Processing document: 251
# [DEBUG] Tokens before processing: 105
# [DEBUG] Tokens after stop-word removal: 51
# [DEBUG] Final tokens: 51
#
# [DEBUG] Processing document: 252
# [DEBUG] Tokens before processing: 265
# [DEBUG] Tokens after stop-word removal: 150
# [DEBUG] Final tokens: 150
#
# [DEBUG] Processing document: 253
# [DEBUG] Tokens before processing: 173
# [DEBUG] Tokens after stop-word removal: 92
# [DEBUG] Final tokens: 92
#
# [DEBUG] Processing document: 254
# [DEBUG] Tokens before processing: 74
# [DEBUG] Tokens after stop-word removal: 43
# [DEBUG] Final tokens: 43
#
# [DEBUG] Processing document: 255
# [DEBUG] Tokens before processing: 217
# [DEBUG] Tokens after stop-word removal: 112
# [DEBUG] Final tokens: 112
#
# [DEBUG] Processing document: 256
# [DEBUG] Tokens before processing: 137
# [DEBUG] Tokens after stop-word removal: 66
# [DEBUG] Final tokens: 66
#
# [DEBUG] Processing document: 257
# [DEBUG] Tokens before processing: 228
# [DEBUG] Tokens after stop-word removal: 111
# [DEBUG] Final tokens: 111
#
# [DEBUG] Processing document: 258
# [DEBUG] Tokens before processing: 70
# [DEBUG] Tokens after stop-word removal: 41
# [DEBUG] Final tokens: 41
#
# [DEBUG] Processing document: 259
# [DEBUG] Tokens before processing: 164
# [DEBUG] Tokens after stop-word removal: 103
# [DEBUG] Final tokens: 103
#
# [DEBUG] Processing document: 260
# [DEBUG] Tokens before processing: 132
# [DEBUG] Tokens after stop-word removal: 76
# [DEBUG] Final tokens: 76
#
# [DEBUG] Processing document: 261
# [DEBUG] Tokens before processing: 166
# [DEBUG] Tokens after stop-word removal: 94
# [DEBUG] Final tokens: 94
#
# [DEBUG] Processing document: 262
# [DEBUG] Tokens before processing: 452
# [DEBUG] Tokens after stop-word removal: 198
# [DEBUG] Final tokens: 198
#
# [DEBUG] Processing document: 263
# [DEBUG] Tokens before processing: 159
# [DEBUG] Tokens after stop-word removal: 86
# [DEBUG] Final tokens: 86
#
# [DEBUG] Processing document: 264
# [DEBUG] Tokens before processing: 68
# [DEBUG] Tokens after stop-word removal: 43
# [DEBUG] Final tokens: 43
#
# [DEBUG] Processing document: 265
# [DEBUG] Tokens before processing: 99
# [DEBUG] Tokens after stop-word removal: 53
# [DEBUG] Final tokens: 53
#
# [DEBUG] Processing document: 266
# [DEBUG] Tokens before processing: 273
# [DEBUG] Tokens after stop-word removal: 137
# [DEBUG] Final tokens: 137
#
# [DEBUG] Processing document: 267
# [DEBUG] Tokens before processing: 217
# [DEBUG] Tokens after stop-word removal: 115
# [DEBUG] Final tokens: 115
#
# [DEBUG] Processing document: 268
# [DEBUG] Tokens before processing: 122
# [DEBUG] Tokens after stop-word removal: 78
# [DEBUG] Final tokens: 78
#
# [DEBUG] Processing document: 269
# [DEBUG] Tokens before processing: 144
# [DEBUG] Tokens after stop-word removal: 86
# [DEBUG] Final tokens: 86
#
# [DEBUG] Processing document: 270
# [DEBUG] Tokens before processing: 221
# [DEBUG] Tokens after stop-word removal: 135
# [DEBUG] Final tokens: 135
#
# [DEBUG] Processing document: 271
# [DEBUG] Tokens before processing: 50
# [DEBUG] Tokens after stop-word removal: 32
# [DEBUG] Final tokens: 32
#
# [DEBUG] Processing document: 272
# [DEBUG] Tokens before processing: 454
# [DEBUG] Tokens after stop-word removal: 263
# [DEBUG] Final tokens: 263
#
# [DEBUG] Processing document: 273
# [DEBUG] Tokens before processing: 115
# [DEBUG] Tokens after stop-word removal: 65
# [DEBUG] Final tokens: 65
#
# [DEBUG] Processing document: 274
# [DEBUG] Tokens before processing: 254
# [DEBUG] Tokens after stop-word removal: 133
# [DEBUG] Final tokens: 133
#
# [DEBUG] Processing document: 275
# [DEBUG] Tokens before processing: 136
# [DEBUG] Tokens after stop-word removal: 86
# [DEBUG] Final tokens: 86
#
# [DEBUG] Processing document: 276
# [DEBUG] Tokens before processing: 221
# [DEBUG] Tokens after stop-word removal: 109
# [DEBUG] Final tokens: 109
#
# [DEBUG] Processing document: 277
# [DEBUG] Tokens before processing: 280
# [DEBUG] Tokens after stop-word removal: 146
# [DEBUG] Final tokens: 146
#
# [DEBUG] Processing document: 278
# [DEBUG] Tokens before processing: 146
# [DEBUG] Tokens after stop-word removal: 80
# [DEBUG] Final tokens: 80
#
# [DEBUG] Processing document: 279
# [DEBUG] Tokens before processing: 125
# [DEBUG] Tokens after stop-word removal: 72
# [DEBUG] Final tokens: 72
#
# [DEBUG] Processing document: 280
# [DEBUG] Tokens before processing: 153
# [DEBUG] Tokens after stop-word removal: 82
# [DEBUG] Final tokens: 82
#
# [DEBUG] Processing document: 281
# [DEBUG] Tokens before processing: 51
# [DEBUG] Tokens after stop-word removal: 28
# [DEBUG] Final tokens: 28
#
# [DEBUG] Processing document: 282
# [DEBUG] Tokens before processing: 233
# [DEBUG] Tokens after stop-word removal: 133
# [DEBUG] Final tokens: 133
#
# [DEBUG] Processing document: 283
# [DEBUG] Tokens before processing: 194
# [DEBUG] Tokens after stop-word removal: 112
# [DEBUG] Final tokens: 112
#
# [DEBUG] Processing document: 284
# [DEBUG] Tokens before processing: 108
# [DEBUG] Tokens after stop-word removal: 59
# [DEBUG] Final tokens: 59
#
# [DEBUG] Processing document: 285
# [DEBUG] Tokens before processing: 67
# [DEBUG] Tokens after stop-word removal: 34
# [DEBUG] Final tokens: 34
#
# [DEBUG] Processing document: 286
# [DEBUG] Tokens before processing: 43
# [DEBUG] Tokens after stop-word removal: 29
# [DEBUG] Final tokens: 29
#
# [DEBUG] Processing document: 287
# [DEBUG] Tokens before processing: 155
# [DEBUG] Tokens after stop-word removal: 89
# [DEBUG] Final tokens: 89
#
# [DEBUG] Processing document: 288
# [DEBUG] Tokens before processing: 209
# [DEBUG] Tokens after stop-word removal: 103
# [DEBUG] Final tokens: 103
#
# [DEBUG] Processing document: 289
# [DEBUG] Tokens before processing: 255
# [DEBUG] Tokens after stop-word removal: 128
# [DEBUG] Final tokens: 128
#
# [DEBUG] Processing document: 290
# [DEBUG] Tokens before processing: 128
# [DEBUG] Tokens after stop-word removal: 72
# [DEBUG] Final tokens: 72
#
# [DEBUG] Processing document: 291
# [DEBUG] Tokens before processing: 73
# [DEBUG] Tokens after stop-word removal: 46
# [DEBUG] Final tokens: 46
#
# [DEBUG] Processing document: 292
# [DEBUG] Tokens before processing: 268
# [DEBUG] Tokens after stop-word removal: 139
# [DEBUG] Final tokens: 139
#
# [DEBUG] Processing document: 293
# [DEBUG] Tokens before processing: 136
# [DEBUG] Tokens after stop-word removal: 75
# [DEBUG] Final tokens: 75
#
# [DEBUG] Processing document: 294
# [DEBUG] Tokens before processing: 277
# [DEBUG] Tokens after stop-word removal: 160
# [DEBUG] Final tokens: 160
#
# [DEBUG] Processing document: 295
# [DEBUG] Tokens before processing: 114
# [DEBUG] Tokens after stop-word removal: 65
# [DEBUG] Final tokens: 65
#
# [DEBUG] Processing document: 296
# [DEBUG] Tokens before processing: 254
# [DEBUG] Tokens after stop-word removal: 129
# [DEBUG] Final tokens: 129
#
# [DEBUG] Processing document: 297
# [DEBUG] Tokens before processing: 155
# [DEBUG] Tokens after stop-word removal: 88
# [DEBUG] Final tokens: 88
#
# [DEBUG] Processing document: 298
# [DEBUG] Tokens before processing: 71
# [DEBUG] Tokens after stop-word removal: 41
# [DEBUG] Final tokens: 41
#
# [DEBUG] Processing document: 299
# [DEBUG] Tokens before processing: 144
# [DEBUG] Tokens after stop-word removal: 79
# [DEBUG] Final tokens: 79
#
# [DEBUG] Processing document: 300
# [DEBUG] Tokens before processing: 268
# [DEBUG] Tokens after stop-word removal: 148
# [DEBUG] Final tokens: 148
#
# [DEBUG] Processing document: 301
# [DEBUG] Tokens before processing: 65
# [DEBUG] Tokens after stop-word removal: 36
# [DEBUG] Final tokens: 36
#
# [DEBUG] Processing document: 302
# [DEBUG] Tokens before processing: 146
# [DEBUG] Tokens after stop-word removal: 78
# [DEBUG] Final tokens: 78
#
# [DEBUG] Processing document: 303
# [DEBUG] Tokens before processing: 85
# [DEBUG] Tokens after stop-word removal: 55
# [DEBUG] Final tokens: 55
#
# [DEBUG] Processing document: 304
# [DEBUG] Tokens before processing: 300
# [DEBUG] Tokens after stop-word removal: 156
# [DEBUG] Final tokens: 156
#
# [DEBUG] Processing document: 305
# [DEBUG] Tokens before processing: 158
# [DEBUG] Tokens after stop-word removal: 101
# [DEBUG] Final tokens: 101
#
# [DEBUG] Processing document: 306
# [DEBUG] Tokens before processing: 168
# [DEBUG] Tokens after stop-word removal: 92
# [DEBUG] Final tokens: 92
#
# [DEBUG] Processing document: 307
# [DEBUG] Tokens before processing: 152
# [DEBUG] Tokens after stop-word removal: 85
# [DEBUG] Final tokens: 85
#
# [DEBUG] Processing document: 308
# [DEBUG] Tokens before processing: 185
# [DEBUG] Tokens after stop-word removal: 92
# [DEBUG] Final tokens: 92
#
# [DEBUG] Processing document: 309
# [DEBUG] Tokens before processing: 203
# [DEBUG] Tokens after stop-word removal: 97
# [DEBUG] Final tokens: 97
#
# [DEBUG] Processing document: 310
# [DEBUG] Tokens before processing: 158
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 311
# [DEBUG] Tokens before processing: 207
# [DEBUG] Tokens after stop-word removal: 114
# [DEBUG] Final tokens: 114
#
# [DEBUG] Processing document: 312
# [DEBUG] Tokens before processing: 82
# [DEBUG] Tokens after stop-word removal: 48
# [DEBUG] Final tokens: 48
#
# [DEBUG] Processing document: 313
# [DEBUG] Tokens before processing: 78
# [DEBUG] Tokens after stop-word removal: 38
# [DEBUG] Final tokens: 38
#
# [DEBUG] Processing document: 314
# [DEBUG] Tokens before processing: 196
# [DEBUG] Tokens after stop-word removal: 110
# [DEBUG] Final tokens: 110
#
# [DEBUG] Processing document: 315
# [DEBUG] Tokens before processing: 492
# [DEBUG] Tokens after stop-word removal: 248
# [DEBUG] Final tokens: 248
#
# [DEBUG] Processing document: 316
# [DEBUG] Tokens before processing: 119
# [DEBUG] Tokens after stop-word removal: 63
# [DEBUG] Final tokens: 63
#
# [DEBUG] Processing document: 317
# [DEBUG] Tokens before processing: 230
# [DEBUG] Tokens after stop-word removal: 129
# [DEBUG] Final tokens: 129
#
# [DEBUG] Processing document: 318
# [DEBUG] Tokens before processing: 145
# [DEBUG] Tokens after stop-word removal: 82
# [DEBUG] Final tokens: 82
#
# [DEBUG] Processing document: 319
# [DEBUG] Tokens before processing: 128
# [DEBUG] Tokens after stop-word removal: 72
# [DEBUG] Final tokens: 72
#
# [DEBUG] Processing document: 320
# [DEBUG] Tokens before processing: 39
# [DEBUG] Tokens after stop-word removal: 24
# [DEBUG] Final tokens: 24
#
# [DEBUG] Processing document: 321
# [DEBUG] Tokens before processing: 110
# [DEBUG] Tokens after stop-word removal: 65
# [DEBUG] Final tokens: 65
#
# [DEBUG] Processing document: 322
# [DEBUG] Tokens before processing: 67
# [DEBUG] Tokens after stop-word removal: 36
# [DEBUG] Final tokens: 36
#
# [DEBUG] Processing document: 323
# [DEBUG] Tokens before processing: 90
# [DEBUG] Tokens after stop-word removal: 50
# [DEBUG] Final tokens: 50
#
# [DEBUG] Processing document: 324
# [DEBUG] Tokens before processing: 81
# [DEBUG] Tokens after stop-word removal: 48
# [DEBUG] Final tokens: 48
#
# [DEBUG] Processing document: 325
# [DEBUG] Tokens before processing: 255
# [DEBUG] Tokens after stop-word removal: 139
# [DEBUG] Final tokens: 139
#
# [DEBUG] Processing document: 326
# [DEBUG] Tokens before processing: 68
# [DEBUG] Tokens after stop-word removal: 45
# [DEBUG] Final tokens: 45
#
# [DEBUG] Processing document: 327
# [DEBUG] Tokens before processing: 95
# [DEBUG] Tokens after stop-word removal: 61
# [DEBUG] Final tokens: 61
#
# [DEBUG] Processing document: 328
# [DEBUG] Tokens before processing: 280
# [DEBUG] Tokens after stop-word removal: 169
# [DEBUG] Final tokens: 169
#
# [DEBUG] Processing document: 329
# [DEBUG] Tokens before processing: 644
# [DEBUG] Tokens after stop-word removal: 360
# [DEBUG] Final tokens: 360
#
# [DEBUG] Processing document: 330
# [DEBUG] Tokens before processing: 109
# [DEBUG] Tokens after stop-word removal: 61
# [DEBUG] Final tokens: 61
#
# [DEBUG] Processing document: 331
# [DEBUG] Tokens before processing: 92
# [DEBUG] Tokens after stop-word removal: 49
# [DEBUG] Final tokens: 49
#
# [DEBUG] Processing document: 332
# [DEBUG] Tokens before processing: 203
# [DEBUG] Tokens after stop-word removal: 114
# [DEBUG] Final tokens: 114
#
# [DEBUG] Processing document: 333
# [DEBUG] Tokens before processing: 74
# [DEBUG] Tokens after stop-word removal: 47
# [DEBUG] Final tokens: 47
#
# [DEBUG] Processing document: 334
# [DEBUG] Tokens before processing: 253
# [DEBUG] Tokens after stop-word removal: 143
# ...
# [DEBUG] Tokens before processing: 252
# [DEBUG] Tokens after stop-word removal: 150
# [DEBUG] Final tokens: 150
#
# [DEBUG] Processing document: 1290
# [DEBUG] Tokens before processing: 223
# [DEBUG] Tokens after stop-word removal: 130
# [DEBUG] Final tokens: 130
#
# [DEBUG] Processing document: 1291
# [DEBUG] Tokens before processing: 275
# [DEBUG] Tokens after stop-word removal: 165
# [DEBUG] Final tokens: 165
#
# [DEBUG] Processing document: 1292
# [DEBUG] Tokens before processing: 274
# [DEBUG] Tokens after stop-word removal: 157
# [DEBUG] Final tokens: 157
#
# [DEBUG] Processing document: 1293
# [DEBUG] Tokens before processing: 58
# [DEBUG] Tokens after stop-word removal: 36
# [DEBUG] Final tokens: 36
#
# [DEBUG] Processing document: 1294
# [DEBUG] Tokens before processing: 192
# [DEBUG] Tokens after stop-word removal: 109
# [DEBUG] Final tokens: 109
#
# [DEBUG] Processing document: 1295
# [DEBUG] Tokens before processing: 159
# [DEBUG] Tokens after stop-word removal: 92
# [DEBUG] Final tokens: 92
#
# [DEBUG] Processing document: 1296
# [DEBUG] Tokens before processing: 192
# [DEBUG] Tokens after stop-word removal: 124
# [DEBUG] Final tokens: 124
#
# [DEBUG] Processing document: 1297
# [DEBUG] Tokens before processing: 136
# [DEBUG] Tokens after stop-word removal: 86
# [DEBUG] Final tokens: 86
#
# [DEBUG] Processing document: 1298
# [DEBUG] Tokens before processing: 122
# [DEBUG] Tokens after stop-word removal: 71
# [DEBUG] Final tokens: 71
#
# [DEBUG] Processing document: 1299
# [DEBUG] Tokens before processing: 63
# [DEBUG] Tokens after stop-word removal: 37
# [DEBUG] Final tokens: 37
#
# [DEBUG] Processing document: 1300
# [DEBUG] Tokens before processing: 300
# [DEBUG] Tokens after stop-word removal: 169
# [DEBUG] Final tokens: 169
#
# [DEBUG] Processing document: 1301
# [DEBUG] Tokens before processing: 187
# [DEBUG] Tokens after stop-word removal: 83
# [DEBUG] Final tokens: 83
#
# [DEBUG] Processing document: 1302
# [DEBUG] Tokens before processing: 213
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 1303
# [DEBUG] Tokens before processing: 235
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 1304
# [DEBUG] Tokens before processing: 163
# [DEBUG] Tokens after stop-word removal: 83
# [DEBUG] Final tokens: 83
#
# [DEBUG] Processing document: 1305
# [DEBUG] Tokens before processing: 89
# [DEBUG] Tokens after stop-word removal: 51
# [DEBUG] Final tokens: 51
#
# [DEBUG] Processing document: 1306
# [DEBUG] Tokens before processing: 55
# [DEBUG] Tokens after stop-word removal: 33
# [DEBUG] Final tokens: 33
#
# [DEBUG] Processing document: 1307
# [DEBUG] Tokens before processing: 278
# [DEBUG] Tokens after stop-word removal: 152
# [DEBUG] Final tokens: 152
#
# [DEBUG] Processing document: 1308
# [DEBUG] Tokens before processing: 107
# [DEBUG] Tokens after stop-word removal: 42
# [DEBUG] Final tokens: 42
#
# [DEBUG] Processing document: 1309
# [DEBUG] Tokens before processing: 239
# [DEBUG] Tokens after stop-word removal: 137
# [DEBUG] Final tokens: 137
#
# [DEBUG] Processing document: 1310
# [DEBUG] Tokens before processing: 299
# [DEBUG] Tokens after stop-word removal: 161
# [DEBUG] Final tokens: 161
#
# [DEBUG] Processing document: 1311
# [DEBUG] Tokens before processing: 79
# [DEBUG] Tokens after stop-word removal: 53
# [DEBUG] Final tokens: 53
#
# [DEBUG] Processing document: 1312
# [DEBUG] Tokens before processing: 130
# [DEBUG] Tokens after stop-word removal: 71
# [DEBUG] Final tokens: 71
#
# [DEBUG] Processing document: 1313
# [DEBUG] Tokens before processing: 661
# [DEBUG] Tokens after stop-word removal: 343
# [DEBUG] Final tokens: 343
#
# [DEBUG] Processing document: 1314
# [DEBUG] Tokens before processing: 77
# [DEBUG] Tokens after stop-word removal: 48
# [DEBUG] Final tokens: 48
#
# [DEBUG] Processing document: 1315
# [DEBUG] Tokens before processing: 154
# [DEBUG] Tokens after stop-word removal: 93
# [DEBUG] Final tokens: 93
#
# [DEBUG] Processing document: 1316
# [DEBUG] Tokens before processing: 239
# [DEBUG] Tokens after stop-word removal: 126
# [DEBUG] Final tokens: 126
#
# [DEBUG] Processing document: 1317
# [DEBUG] Tokens before processing: 47
# [DEBUG] Tokens after stop-word removal: 30
# [DEBUG] Final tokens: 30
#
# [DEBUG] Processing document: 1318
# [DEBUG] Tokens before processing: 94
# [DEBUG] Tokens after stop-word removal: 62
# [DEBUG] Final tokens: 62
#
# [DEBUG] Processing document: 1319
# [DEBUG] Tokens before processing: 250
# [DEBUG] Tokens after stop-word removal: 148
# [DEBUG] Final tokens: 148
#
# [DEBUG] Processing document: 1320
# [DEBUG] Tokens before processing: 208
# [DEBUG] Tokens after stop-word removal: 114
# [DEBUG] Final tokens: 114
#
# [DEBUG] Processing document: 1321
# [DEBUG] Tokens before processing: 268
# [DEBUG] Tokens after stop-word removal: 148
# [DEBUG] Final tokens: 148
#
# [DEBUG] Processing document: 1322
# [DEBUG] Tokens before processing: 257
# [DEBUG] Tokens after stop-word removal: 131
# [DEBUG] Final tokens: 131
#
# [DEBUG] Processing document: 1323
# [DEBUG] Tokens before processing: 129
# [DEBUG] Tokens after stop-word removal: 64
# [DEBUG] Final tokens: 64
#
# [DEBUG] Processing document: 1324
# [DEBUG] Tokens before processing: 169
# [DEBUG] Tokens after stop-word removal: 88
# [DEBUG] Final tokens: 88
#
# [DEBUG] Processing document: 1325
# [DEBUG] Tokens before processing: 342
# [DEBUG] Tokens after stop-word removal: 169
# [DEBUG] Final tokens: 169
#
# [DEBUG] Processing document: 1326
# [DEBUG] Tokens before processing: 157
# [DEBUG] Tokens after stop-word removal: 95
# [DEBUG] Final tokens: 95
#
# [DEBUG] Processing document: 1327
# [DEBUG] Tokens before processing: 159
# [DEBUG] Tokens after stop-word removal: 78
# [DEBUG] Final tokens: 78
#
# [DEBUG] Processing document: 1328
# [DEBUG] Tokens before processing: 231
# [DEBUG] Tokens after stop-word removal: 132
# [DEBUG] Final tokens: 132
#
# [DEBUG] Processing document: 1329
# [DEBUG] Tokens before processing: 184
# [DEBUG] Tokens after stop-word removal: 92
# [DEBUG] Final tokens: 92
#
# [DEBUG] Processing document: 1330
# [DEBUG] Tokens before processing: 216
# [DEBUG] Tokens after stop-word removal: 124
# [DEBUG] Final tokens: 124
#
# [DEBUG] Processing document: 1331
# [DEBUG] Tokens before processing: 101
# [DEBUG] Tokens after stop-word removal: 65
# [DEBUG] Final tokens: 65
#
# [DEBUG] Processing document: 1332
# [DEBUG] Tokens before processing: 142
# [DEBUG] Tokens after stop-word removal: 87
# [DEBUG] Final tokens: 87
#
# [DEBUG] Processing document: 1333
# [DEBUG] Tokens before processing: 247
# [DEBUG] Tokens after stop-word removal: 136
# [DEBUG] Final tokens: 136
#
# [DEBUG] Processing document: 1334
# [DEBUG] Tokens before processing: 155
# [DEBUG] Tokens after stop-word removal: 90
# [DEBUG] Final tokens: 90
#
# [DEBUG] Processing document: 1335
# [DEBUG] Tokens before processing: 216
# [DEBUG] Tokens after stop-word removal: 98
# [DEBUG] Final tokens: 98
#
# [DEBUG] Processing document: 1336
# [DEBUG] Tokens before processing: 198
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 1337
# [DEBUG] Tokens before processing: 171
# [DEBUG] Tokens after stop-word removal: 90
# [DEBUG] Final tokens: 90
#
# [DEBUG] Processing document: 1338
# [DEBUG] Tokens before processing: 200
# [DEBUG] Tokens after stop-word removal: 118
# [DEBUG] Final tokens: 118
#
# [DEBUG] Processing document: 1339
# [DEBUG] Tokens before processing: 232
# [DEBUG] Tokens after stop-word removal: 141
# [DEBUG] Final tokens: 141
#
# [DEBUG] Processing document: 1340
# [DEBUG] Tokens before processing: 120
# [DEBUG] Tokens after stop-word removal: 70
# [DEBUG] Final tokens: 70
#
# [DEBUG] Processing document: 1341
# [DEBUG] Tokens before processing: 217
# [DEBUG] Tokens after stop-word removal: 123
# [DEBUG] Final tokens: 123
#
# [DEBUG] Processing document: 1342
# [DEBUG] Tokens before processing: 292
# [DEBUG] Tokens after stop-word removal: 143
# [DEBUG] Final tokens: 143
#
# [DEBUG] Processing document: 1343
# [DEBUG] Tokens before processing: 278
# [DEBUG] Tokens after stop-word removal: 142
# [DEBUG] Final tokens: 142
#
# [DEBUG] Processing document: 1344
# [DEBUG] Tokens before processing: 217
# [DEBUG] Tokens after stop-word removal: 130
# [DEBUG] Final tokens: 130
#
# [DEBUG] Processing document: 1345
# [DEBUG] Tokens before processing: 138
# [DEBUG] Tokens after stop-word removal: 74
# [DEBUG] Final tokens: 74
#
# [DEBUG] Processing document: 1346
# [DEBUG] Tokens before processing: 119
# [DEBUG] Tokens after stop-word removal: 69
# [DEBUG] Final tokens: 69
#
# [DEBUG] Processing document: 1347
# [DEBUG] Tokens before processing: 247
# [DEBUG] Tokens after stop-word removal: 153
# [DEBUG] Final tokens: 153
#
# [DEBUG] Processing document: 1348
# [DEBUG] Tokens before processing: 85
# [DEBUG] Tokens after stop-word removal: 56
# [DEBUG] Final tokens: 56
#
# [DEBUG] Processing document: 1349
# [DEBUG] Tokens before processing: 220
# [DEBUG] Tokens after stop-word removal: 126
# [DEBUG] Final tokens: 126
#
# [DEBUG] Processing document: 1350
# [DEBUG] Tokens before processing: 124
# [DEBUG] Tokens after stop-word removal: 72
# [DEBUG] Final tokens: 72
#
# [DEBUG] Processing document: 1351
# [DEBUG] Tokens before processing: 296
# [DEBUG] Tokens after stop-word removal: 167
# [DEBUG] Final tokens: 167
#
# [DEBUG] Processing document: 1352
# [DEBUG] Tokens before processing: 256
# [DEBUG] Tokens after stop-word removal: 144
# [DEBUG] Final tokens: 144
#
# [DEBUG] Processing document: 1353
# [DEBUG] Tokens before processing: 137
# [DEBUG] Tokens after stop-word removal: 64
# [DEBUG] Final tokens: 64
#
# [DEBUG] Processing document: 1354
# [DEBUG] Tokens before processing: 168
# [DEBUG] Tokens after stop-word removal: 84
# [DEBUG] Final tokens: 84
#
# [DEBUG] Processing document: 1355
# [DEBUG] Tokens before processing: 207
# [DEBUG] Tokens after stop-word removal: 111
# [DEBUG] Final tokens: 111
#
# [DEBUG] Processing document: 1356
# [DEBUG] Tokens before processing: 300
# [DEBUG] Tokens after stop-word removal: 172
# [DEBUG] Final tokens: 172
#
# [DEBUG] Processing document: 1357
# [DEBUG] Tokens before processing: 53
# [DEBUG] Tokens after stop-word removal: 33
# [DEBUG] Final tokens: 33
#
# [DEBUG] Processing document: 1358
# [DEBUG] Tokens before processing: 48
# [DEBUG] Tokens after stop-word removal: 31
# [DEBUG] Final tokens: 31
#
# [DEBUG] Processing document: 1359
# [DEBUG] Tokens before processing: 84
# [DEBUG] Tokens after stop-word removal: 58
# [DEBUG] Final tokens: 58
#
# [DEBUG] Processing document: 1360
# [DEBUG] Tokens before processing: 133
# [DEBUG] Tokens after stop-word removal: 65
# [DEBUG] Final tokens: 65
#
# [DEBUG] Processing document: 1361
# [DEBUG] Tokens before processing: 161
# [DEBUG] Tokens after stop-word removal: 91
# [DEBUG] Final tokens: 91
#
# [DEBUG] Processing document: 1362
# [DEBUG] Tokens before processing: 150
# [DEBUG] Tokens after stop-word removal: 86
# [DEBUG] Final tokens: 86
#
# [DEBUG] Processing document: 1363
# [DEBUG] Tokens before processing: 168
# [DEBUG] Tokens after stop-word removal: 89
# [DEBUG] Final tokens: 89
#
# [DEBUG] Processing document: 1364
# [DEBUG] Tokens before processing: 222
# [DEBUG] Tokens after stop-word removal: 111
# [DEBUG] Final tokens: 111
#
# [DEBUG] Processing document: 1365
# [DEBUG] Tokens before processing: 160
# [DEBUG] Tokens after stop-word removal: 90
# [DEBUG] Final tokens: 90
#
# [DEBUG] Processing document: 1366
# [DEBUG] Tokens before processing: 196
# [DEBUG] Tokens after stop-word removal: 123
# [DEBUG] Final tokens: 123
#
# [DEBUG] Processing document: 1367
# [DEBUG] Tokens before processing: 93
# [DEBUG] Tokens after stop-word removal: 56
# [DEBUG] Final tokens: 56
#
# [DEBUG] Processing document: 1368
# [DEBUG] Tokens before processing: 86
# [DEBUG] Tokens after stop-word removal: 52
# [DEBUG] Final tokens: 52
#
# [DEBUG] Processing document: 1369
# [DEBUG] Tokens before processing: 84
# [DEBUG] Tokens after stop-word removal: 44
# [DEBUG] Final tokens: 44
#
# [DEBUG] Processing document: 1370
# [DEBUG] Tokens before processing: 254
# [DEBUG] Tokens after stop-word removal: 122
# [DEBUG] Final tokens: 122
#
# [DEBUG] Processing document: 1371
# [DEBUG] Tokens before processing: 181
# [DEBUG] Tokens after stop-word removal: 110
# [DEBUG] Final tokens: 110
#
# [DEBUG] Processing document: 1372
# [DEBUG] Tokens before processing: 199
# [DEBUG] Tokens after stop-word removal: 107
# [DEBUG] Final tokens: 107
#
# [DEBUG] Processing document: 1373
# [DEBUG] Tokens before processing: 305
# [DEBUG] Tokens after stop-word removal: 174
# [DEBUG] Final tokens: 174
#
# [DEBUG] Processing document: 1374
# [DEBUG] Tokens before processing: 144
# [DEBUG] Tokens after stop-word removal: 84
# [DEBUG] Final tokens: 84
#
# [DEBUG] Processing document: 1375
# [DEBUG] Tokens before processing: 318
# [DEBUG] Tokens after stop-word removal: 172
# [DEBUG] Final tokens: 172
#
# [DEBUG] Processing document: 1376
# [DEBUG] Tokens before processing: 89
# [DEBUG] Tokens after stop-word removal: 50
# [DEBUG] Final tokens: 50
#
# [DEBUG] Processing document: 1377
# [DEBUG] Tokens before processing: 113
# [DEBUG] Tokens after stop-word removal: 66
# [DEBUG] Final tokens: 66
#
# [DEBUG] Processing document: 1378
# [DEBUG] Tokens before processing: 88
# [DEBUG] Tokens after stop-word removal: 56
# [DEBUG] Final tokens: 56
#
# [DEBUG] Processing document: 1379
# [DEBUG] Tokens before processing: 114
# [DEBUG] Tokens after stop-word removal: 62
# [DEBUG] Final tokens: 62
#
# [DEBUG] Processing document: 1380
# [DEBUG] Tokens before processing: 309
# [DEBUG] Tokens after stop-word removal: 155
# [DEBUG] Final tokens: 155
#
# [DEBUG] Processing document: 1381
# [DEBUG] Tokens before processing: 311
# [DEBUG] Tokens after stop-word removal: 175
# [DEBUG] Final tokens: 175
#
# [DEBUG] Processing document: 1382
# [DEBUG] Tokens before processing: 329
# [DEBUG] Tokens after stop-word removal: 163
# [DEBUG] Final tokens: 163
#
# [DEBUG] Processing document: 1383
# [DEBUG] Tokens before processing: 235
# [DEBUG] Tokens after stop-word removal: 122
# [DEBUG] Final tokens: 122
#
# [DEBUG] Processing document: 1384
# [DEBUG] Tokens before processing: 177
# [DEBUG] Tokens after stop-word removal: 92
# [DEBUG] Final tokens: 92
#
# [DEBUG] Processing document: 1385
# [DEBUG] Tokens before processing: 181
# [DEBUG] Tokens after stop-word removal: 98
# [DEBUG] Final tokens: 98
#
# [DEBUG] Processing document: 1386
# [DEBUG] Tokens before processing: 246
# [DEBUG] Tokens after stop-word removal: 144
# [DEBUG] Final tokens: 144
#
# [DEBUG] Processing document: 1387
# [DEBUG] Tokens before processing: 254
# [DEBUG] Tokens after stop-word removal: 117
# [DEBUG] Final tokens: 117
#
# [DEBUG] Processing document: 1388
# [DEBUG] Tokens before processing: 110
# [DEBUG] Tokens after stop-word removal: 60
# [DEBUG] Final tokens: 60
#
# [DEBUG] Processing document: 1389
# [DEBUG] Tokens before processing: 137
# [DEBUG] Tokens after stop-word removal: 80
# [DEBUG] Final tokens: 80
#
# [DEBUG] Processing document: 1390
# [DEBUG] Tokens before processing: 178
# [DEBUG] Tokens after stop-word removal: 98
# [DEBUG] Final tokens: 98
#
# [DEBUG] Processing document: 1391
# [DEBUG] Tokens before processing: 225
# [DEBUG] Tokens after stop-word removal: 123
# [DEBUG] Final tokens: 123
#
# [DEBUG] Processing document: 1392
# [DEBUG] Tokens before processing: 337
# [DEBUG] Tokens after stop-word removal: 166
# [DEBUG] Final tokens: 166
#
# [DEBUG] Processing document: 1393
# [DEBUG] Tokens before processing: 194
# [DEBUG] Tokens after stop-word removal: 111
# [DEBUG] Final tokens: 111
#
# [DEBUG] Processing document: 1394
# [DEBUG] Tokens before processing: 137
# [DEBUG] Tokens after stop-word removal: 93
# [DEBUG] Final tokens: 93
#
# [DEBUG] Processing document: 1395
# [DEBUG] Tokens before processing: 81
# [DEBUG] Tokens after stop-word removal: 68
# [DEBUG] Final tokens: 68
#
# [DEBUG] Processing document: 1396
# [DEBUG] Tokens before processing: 123
# [DEBUG] Tokens after stop-word removal: 67
# [DEBUG] Final tokens: 67
#
# [DEBUG] Processing document: 1397
# [DEBUG] Tokens before processing: 89
# [DEBUG] Tokens after stop-word removal: 57
# [DEBUG] Final tokens: 57
#
# [DEBUG] Processing document: 1398
# [DEBUG] Tokens before processing: 214
# [DEBUG] Tokens after stop-word removal: 104
# [DEBUG] Final tokens: 104
#
# [DEBUG] Processing document: 1399
# [DEBUG] Tokens before processing: 85
# [DEBUG] Tokens after stop-word removal: 49
# [DEBUG] Final tokens: 49
#
# [DEBUG] Processing document: 1400
# [DEBUG] Tokens before processing: 114
# [DEBUG] Tokens after stop-word removal: 71
# [DEBUG] Final tokens: 71
# [DEBUG] Preprocessing complete
# [DEBUG] Documents processed: 1400
# [DEBUG] Output file: Information_Retrieval_Group_Project_processed.all

# %% [markdown]
# # Indexing

# %%
from collections import defaultdict

GROUP_NAME="Information_Retrieval_Group_Project"

inputfile=GROUP_NAME+"_processed.all"
indexfile=GROUP_NAME+"_cran.index"

# %%
# Adds one document to the postings
def adddoc(postings,docid,terms):
    for term in terms:
        postings[term].append(docid)


# Builds the inverted index
def makeindex(name):
    postings=defaultdict(list)
    seenids=set()

    docid=None
    terms=set()
    sawtokens=False

    with open(name,"r",encoding="utf-8") as file:
        for lineno,raw in enumerate(file,1):
            line=raw.strip()

            if not line:
                continue

            # Starts a new document
            if line.startswith(".I "):
                if docid is not None:
                    if not sawtokens:
                        raise ValueError(
                            f"missing .S for document {docid}"
                        )

                    adddoc(postings,docid,terms)

                parts=line.split()

                if len(parts)!=2 or not parts[1].isdigit():
                    raise ValueError(
                        f"invalid .I tag at line {lineno}"
                    )

                docid=int(parts[1])

                if docid in seenids:
                    raise ValueError(
                        f"duplicate document id {docid}"
                    )

                seenids.add(docid)
                terms=set()
                sawtokens=False

            # Starts the token section
            elif line==".S":
                if docid is None or sawtokens:
                    raise ValueError(
                        f"invalid .S tag at line {lineno}"
                    )

                sawtokens=True

            # Rejects unexpected tags
            elif line.startswith("."):
                raise ValueError(
                    f"unknown tag at line {lineno}: {line}"
                )

            # Stores the terms of the current document
            else:
                if docid is None or not sawtokens:
                    raise ValueError(
                        f"tokens outside .S at line {lineno}"
                    )

                terms.update(line.split())

    # Adds the last document
    if docid is not None:
        if not sawtokens:
            raise ValueError(
                f"missing .S for document {docid}"
            )

        adddoc(postings,docid,terms)

    if not seenids:
        raise ValueError("no documents found")

    return dict(postings),max(seenids),len(seenids)

# %%
# Writes the index to a file
def saveindex(name,postings,maxid):
    with open(name,"w",encoding="utf-8",newline="\n") as file:
        file.write(f"{len(postings)}, {maxid}\n")

        for term in sorted(postings):
            docs=",".join(map(str,postings[term]))
            file.write(f"{term} {docs}\n")


postings,maxid,doccount=makeindex(inputfile)
saveindex(indexfile,postings,maxid)

print("documents indexed:",doccount)
print("vocabulary size:",len(postings))
print("maximum document id:",maxid)
print("posting pairs:",sum(len(docs) for docs in postings.values()))
print("index file:",indexfile)
# Out:
# documents indexed: 1400
# vocabulary size: 4188
# maximum document id: 1400
# posting pairs: 77782
# index file: Information_Retrieval_Group_Project_cran.index

# %%
# Checks the generated index
def checkindex(name,postings,maxid):
    with open(name,"r",encoding="utf-8") as file:
        head=file.readline().strip()
        expected=f"{len(postings)}, {maxid}"

        if head!=expected:
            raise AssertionError("incorrect index header")

        lastterm=None
        count=0

        for lineno,raw in enumerate(file,2):
            line=raw.rstrip("\n")

            if " " not in line:
                raise AssertionError(
                    f"invalid index line {lineno}"
                )

            term,docs=line.split(" ",1)

            try:
                docids=[int(doc) for doc in docs.split(",")]
            except ValueError:
                raise AssertionError(
                    f"invalid document id at line {lineno}"
                )

            if lastterm is not None and term<=lastterm:
                raise AssertionError(
                    f"terms not sorted at line {lineno}"
                )

            if docids!=sorted(set(docids)):
                raise AssertionError(
                    f"postings not sorted or duplicated at line {lineno}"
                )

            if docids!=postings.get(term):
                raise AssertionError(
                    f"incorrect postings at line {lineno}"
                )

            if any(doc<1 or doc>maxid for doc in docids):
                raise AssertionError(
                    f"document id out of range at line {lineno}"
                )

            lastterm=term
            count+=1

        if count!=len(postings):
            raise AssertionError(
                "vocabulary size does not match index lines"
            )

    print("index correctness check passed")


checkindex(indexfile,postings,maxid)
# Out:
# index correctness check passed

# %% [markdown]
# # Boolean Search

# %%
# Load stopwords from file
stop_words=set(load_stopwords("stopwords.txt"))

def load_idx(filename):
    # Read the inverted index from disk.
    idx={}
    with open(filename,"r",encoding="utf-8") as f:
        header=f.readline().strip()
        if not header:
            return idx
        for raw_line in f:
            line=raw_line.rstrip("\n")
            if not line:
                continue
            term,doc_str=line.split(" ",1)
            docs=[int(d) for d in doc_str.split(",")]
            idx[term]=docs
    return idx

# Load the index map
idx_map=load_idx(indexfile)

def intersect_postings(a_list,b_list):
    # Two-pointer merge for finding common docs
    i,j=0,0
    hits=[]
    while i<len(a_list) and j<len(b_list):
        if a_list[i]==b_list[j]:
            hits.append(a_list[i])
            i+=1
            j+=1
        elif a_list[i]<b_list[j]:
            i+=1
        else:
            j+=1
    return hits

def union_postings(a_list,b_list):
    # Two-pointer merge for finding all docs.
    i,j=0,0
    hits=[]
    while i<len(a_list) and j<len(b_list):
        if a_list[i]==b_list[j]:
            hits.append(a_list[i])
            i+=1
            j+=1
        elif a_list[i]<b_list[j]:
            hits.append(a_list[i])
            i+=1
        else:
            hits.append(b_list[j])
            j+=1
    while i<len(a_list):
        hits.append(a_list[i])
        i+=1
    while j<len(b_list):
        hits.append(b_list[j])
        j+=1
    return hits

def process_term(term,stemmer,sw_set):
    # Normalize, strip stopwords, and stem a query term.
    parts=tokenize(term)
    parts=normalize(parts)
    parts=remove_stopwords(parts,sw_set)
    parts=stem(parts,stemmer)
    return parts

def run_query(q_str,stemmer,sw_set):
    # Parse and execute a simple Boolean query.
    parts=q_str.strip().split()
    if not parts:
        return []
    
    # Single term query
    if len(parts)==1:
        word=parts[0]
        tokens=process_term(word,stemmer,sw_set)
        if not tokens:
            return []
        return idx_map.get(tokens[0],[])
    
    # Two-term AND/OR query
    if len(parts)==3:
        term1,op,term2=parts
        op=op.upper()
        if op not in ("AND","OR"):
            raise ValueError(f"Unsupported operator: '{op}'")
        
        t1=process_term(term1,stemmer,sw_set)
        t2=process_term(term2,stemmer,sw_set)
        
        p1=idx_map.get(t1[0],[]) if t1 else []
        p2=idx_map.get(t2[0],[]) if t2 else []
        
        if op=="AND":
            return intersect_postings(p1,p2)
        else:
            return union_postings(p1,p2)
    
    raise ValueError("Invalid query format")

def execute_query(query,q_id):
    # Run a query and save results to <q_id>.txt.
    stemmer=PorterStemmer()
    matches=run_query(query,stemmer,stop_words)
    
    path=f"{q_id}.txt"
    with open(path,"w",encoding="utf-8") as out:
        for doc_id in matches:
            out.write(f"{doc_id}\n")
    
    print(f"[SUCCESS] Query: '{query}' | Match count: {len(matches)} | Output: {path}")
    return matches
# Out:
# [DEBUG] Loaded 358 stop words

# %%
# testing with few queries
execute_query("aerodynamic AND slipstream", "q1")
execute_query("boundary OR layer", "q2")
execute_query("experimental AND destalling", "q3")
# Out:
# [SUCCESS] Query: 'aerodynamic AND slipstream' | Match count: 5 | Output: q1.txt
# [SUCCESS] Query: 'boundary OR layer' | Match count: 513 | Output: q2.txt
# [SUCCESS] Query: 'experimental AND destalling' | Match count: 2 | Output: q3.txt
# [1, 484]

# %%
import bisect
import timeit

# intersect two lists using binary search
def intersect_postings_binary_optimized(a_list,b_list):
    if len(a_list)>len(b_list):
        a_list,b_list=b_list,a_list
        
    hits=[]
    left=0
    for doc_id in a_list:
        # binary search in b_list starting from left
        pos=bisect.bisect_left(b_list,doc_id,lo=left)
        if pos<len(b_list) and b_list[pos]==doc_id:
            hits.append(doc_id)
            left=pos+1
        else:
            left=pos
    return hits

# union two lists using binary search
def union_postings_binary(a_list,b_list):
    if len(a_list)>len(b_list):
        a_list,b_list=b_list,a_list
        
    res=list(b_list)
    left=0
    for doc_id in a_list:
        # binary search for insertion point
        pos=bisect.bisect_left(res,doc_id,lo=left)
        if pos==len(res) or res[pos]!=doc_id:
            res.insert(pos,doc_id)
            left=pos+1
        else:
            left=pos
    return res

# find two terms with different sizes that share common documents
sorted_terms=sorted(idx_map.keys(),key=lambda k:len(idx_map[k]))
term_large=sorted_terms[-1]
p_large_set=set(idx_map[term_large])
term_small=None
for term in sorted_terms:
    if term!=term_large:
        p_curr=idx_map[term]
        if len(p_large_set.intersection(p_curr))>0 and len(p_curr)<len(idx_map[term_large])//10:
            term_small=term
            break
if term_small is None:
    term_small=sorted_terms[0]

p_small=idx_map[term_small]
p_large=idx_map[term_large]

print(f"Postings list size for '{term_small}': {len(p_small)}")
print(f"Postings list size for '{term_large}': {len(p_large)}")

# verify both return the same matches
and_two_pointer=intersect_postings(p_small,p_large)
and_binary=intersect_postings_binary_optimized(p_small,p_large)
or_two_pointer=union_postings(p_small,p_large)
or_binary=union_postings_binary(p_small,p_large)

print(f"AND results are identical: {and_two_pointer==and_binary}")
print(f"OR results are identical: {or_two_pointer==or_binary}")
print(f"Intersecting documents: {and_binary}")

# benchmark both approaches over 10000 runs
t_and_two_pointer=timeit.timeit(lambda:intersect_postings(p_small,p_large),number=10000)
t_and_binary=timeit.timeit(lambda:intersect_postings_binary_optimized(p_small,p_large),number=10000)
t_or_two_pointer=timeit.timeit(lambda:union_postings(p_small,p_large),number=10000)
t_or_binary=timeit.timeit(lambda:union_postings_binary(p_small,p_large),number=10000)

print(f"\nPerformance Comparison (10,000 runs):")
print(f"AND (Two-pointer merge): {t_and_two_pointer:.5f} seconds")
print(f"AND (Optimized Binary):   {t_and_binary:.5f} seconds")
print(f"AND Speedup:             {t_and_two_pointer/t_and_binary:.2f}x\n")
print(f"OR (Two-pointer merge):  {t_or_two_pointer:.5f} seconds")
print(f"OR (Binary Insertion):   {t_or_binary:.5f} seconds")
print(f"OR Speedup:              {t_or_two_pointer/t_or_binary:.2f}x")
# Out:
# Postings list size for 'abbrevi': 1
# Postings list size for 'flow': 730
# AND results are identical: True
# OR results are identical: True
# Intersecting documents: [122]
#
# Performance Comparison (10,000 runs):
# AND (Two-pointer merge): 0.07880 seconds
# AND (Optimized Binary):   0.00288 seconds
# AND Speedup:             27.32x
#
# OR (Two-pointer merge):  0.42834 seconds
# OR (Binary Insertion):   0.00781 seconds
# OR Speedup:              54.85x

# %%
import math
import timeit

# intersect two lists using skip pointers
def intersect_postings_skips(a_list, b_list):
    i, j = 0, 0
    hits = []
    step_a = int(math.sqrt(len(a_list)))
    step_b = int(math.sqrt(len(b_list)))
    
    while i < len(a_list) and j < len(b_list):
        if a_list[i] == b_list[j]:
            hits.append(a_list[i])
            i += 1
            j += 1
        elif a_list[i] < b_list[j]:
            # check if we can skip ahead in a_list
            if step_a > 1 and i + step_a < len(a_list) and a_list[i + step_a] <= b_list[j]:
                while i + step_a < len(a_list) and a_list[i + step_a] <= b_list[j]:
                    i += step_a
            else:
                i += 1
        else:
            # check if we can skip ahead in b_list
            if step_b > 1 and j + step_b < len(b_list) and b_list[j + step_b] <= a_list[i]:
                while j + step_b < len(b_list) and b_list[j + step_b] <= a_list[i]:
                    j += step_b
            else:
                j += 1
    return hits

# find two terms with different sizes that share common documents
all_terms = sorted(idx_map.keys(), key=lambda k: len(idx_map[k]))
big_term = all_terms[-1]
big_docs = set(idx_map[big_term])
small_term = None

for term in all_terms:
    if term != big_term:
        current = idx_map[term]
        if big_docs.intersection(current):
            if len(current) < len(idx_map[big_term]) // 10:
                small_term = term
                break

if not small_term:
    small_term = all_terms[0]

small_docs = idx_map[small_term]
big_docs_list = idx_map[big_term]

print(f"Comparing queries for terms: '{small_term}' and '{big_term}'")
print(f"Postings list size for '{small_term}': {len(small_docs)}")
print(f"Postings list size for '{big_term}': {len(big_docs_list)}")

# verify the skip list method matches the two-pointer results
and_two_pointer = intersect_postings(small_docs, big_docs_list)
and_skips = intersect_postings_skips(small_docs, big_docs_list)
print(f"AND with skips results are identical: {and_two_pointer == and_skips}")

# benchmark intersection and union over 10000 runs
t_and_two_pointer = timeit.timeit(lambda: intersect_postings(small_docs, big_docs_list), number=10000)
t_and_binary = timeit.timeit(lambda: intersect_postings_binary_optimized(small_docs, big_docs_list), number=10000)
t_and_skips = timeit.timeit(lambda: intersect_postings_skips(small_docs, big_docs_list), number=10000)

t_or_two_pointer = timeit.timeit(lambda: union_postings(small_docs, big_docs_list), number=10000)
t_or_binary = timeit.timeit(lambda: union_postings_binary(small_docs, big_docs_list), number=10000)

print(f"\nAND Performance Comparison (10,000 runs):")
print(f"Two-pointer merge: {t_and_two_pointer:.5f} seconds")
print(f"Optimized Binary:   {t_and_binary:.5f} seconds")
print(f"Skip Pointer merge: {t_and_skips:.5f} seconds")

print(f"\nOR Performance Comparison (10,000 runs):")
print(f"Two-pointer merge: {t_or_two_pointer:.5f} seconds")
print(f"Binary Insertion:   {t_or_binary:.5f} seconds")
print(f"Skip Pointer union: Not Applicable (skipping cannot be used in union)")
# Out:
# Comparing queries for terms: 'abbrevi' and 'flow'
# Postings list size for 'abbrevi': 1
# Postings list size for 'flow': 730
# AND with skips results are identical: True
#
# AND Performance Comparison (10,000 runs):
# Two-pointer merge: 0.07600 seconds
# Optimized Binary:   0.00256 seconds
# Skip Pointer merge: 0.04266 seconds
#
# OR Performance Comparison (10,000 runs):
# Two-pointer merge: 0.42768 seconds
# Binary Insertion:   0.00746 seconds
# Skip Pointer union: Not Applicable (skipping cannot be used in union)
